# %% [markdown]
# # Imports

# %%
# pip install selenium 
# download chromedriver: https://sites.google.com/a/chromium.org/chromedriver/downloads      

from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup
import pickle
import time
import os
import requests
import re
import pandas as pd
import csv
import pandas as pd
import emoji

# %% [markdown]
# # Data Cleaning

# %%
# put insta handles of free agent ballers into a list
columns = ['insta_handles']
data = pd.read_csv('/Users/cyrusrustomji/Documents/metis/personal_metis/passion_projects/bball_4/Data/insta_handles.csv',names=columns)
insta = data.insta_handles.tolist()

# %%
# put insta handles of free agent ballers into a list
columns3 = ['players_names']
data3 = pd.read_csv('/Users/cyrusrustomji/Documents/metis/personal_metis/passion_projects/bball_4/Data/players_names.csv',names=columns3)
players2 = data3.players_names.tolist()

# %%
# put insta handles of free agent ballers into a list
columns2 = ['players_names']
data2 = pd.read_csv('/Users/cyrusrustomji/Documents/metis/personal_metis/passion_projects/bball_4/Data/players_names.csv',names=columns2)
players = data2.players_names.tolist()

# %%
# put instagram links of ballers into a list

site = "https://www.instagram.com/"
new_site = []
for i in insta:
    new_site.append(site + i + '/')
print(new_site)
# Out:
# ['https://www.instagram.com/kingjames/', 'https://www.instagram.com/kevindurant/', 'https://www.instagram.com/cp3/', 'https://www.instagram.com/ygtrece/', 'https://www.instagram.com/boogiecousins/', 'https://www.instagram.com/ccapela15/', 'https://www.instagram.com/deandre/', 'https://www.instagram.com/original00g/', 'https://www.instagram.com/juliusrandle30/', 'https://www.instagram.com/jabariparker/', 'https://www.instagram.com/isaiahthomas/', 'https://www.instagram.com/rekehavoc1/', 'https://www.instagram.com/zachlavine8/', 'https://www.instagram.com/carmeloanthony/', 'https://www.instagram.com/_dfavors15/', 'https://www.instagram.com/eneskanter11/', 'https://www.instagram.com/willthethrillb5/', 'https://www.instagram.com/bosnianbeast27/', 'https://www.instagram.com/dwyanewade/', 'https://www.instagram.com/brookiethewookie11/', 'https://www.instagram.com/hoodie5/', 'https://www.instagram.com/swish41/', 'https://www.instagram.com/caldwellpope/', 'https://www.instagram.com/rajonrondo/', 'https://www.instagram.com/teamslowmo/', 'https://www.instagram.com/austinjrivers/', 'https://www.instagram.com/wayne_elli/', 'https://www.instagram.com/moosemonroe15/', 'https://www.instagram.com/fredvanvleet/', 'https://www.instagram.com/lucmbahamoute/', 'https://www.instagram.com/michael8easley/', 'https://www.instagram.com/rudygay/', 'https://www.instagram.com/illwil21/', 'https://www.instagram.com/ersanilyasova7/', 'https://www.instagram.com/jlin7/', 'https://www.instagram.com/milosteodosic4/', 'https://www.instagram.com/shabazznap13r/', 'https://www.instagram.com/mbeli21/', 'https://www.instagram.com/_tonyparker09/', 'https://www.instagram.com/joeharris__12/', 'https://www.instagram.com/kyle.oquinn/', 'https://www.instagram.com/daanteee/', 'https://www.instagram.com/stephensonlance/', 'https://www.instagram.com/nerlensnoel3/', 'https://www.instagram.com/d_dedmon3/', 'https://www.instagram.com/35_fitz/', 'https://www.instagram.com/unclejeffgreen/', 'https://www.instagram.com/iamamirjohnson/', 'https://www.instagram.com/eddavisxvii/', 'https://www.instagram.com/greenranger14/', 'https://www.instagram.com/supermariohezonja/', 'https://www.instagram.com/nemanjabjelica8/', 'https://www.instagram.com/zazapachulia/', 'https://www.instagram.com/joejohnson247/', 'https://www.instagram.com/yogiferre11/', 'https://www.instagram.com/sdotcurry/', 'https://www.instagram.com/bkw34/', 'https://www.instagram.com/dougmcd03/']

# %% [raw]
# d = {}
# p = 0
# captions = []
# for i in new_site:
#     driver.get(i)
#     lenOfPage = driver.execute_script("window.scrollTo(0, document.body.scrollHeight);var lenOfPage=document.body.scrollHeight;return lenOfPage;")
#     match = False
#     while(match==False):
#         lastCount = lenOfPage
#         time.sleep(3)
#         lenOfPage = driver.execute_script("window.scrollTo(0, document.body.scrollHeight);var lenOfPage=document.body.scrollHeight;return lenOfPage;")
#         if lastCount==lenOfPage:
#             match=True
# #     finds all '_2di5p' classes
#     innerHTML = driver.execute_script("return document.body.innerHTML")
#     soup = BeautifulSoup(innerHTML,"lxml")
#     followers = soup.find_all('img', {'class':'FFVAD'})
#     n = 0
#     # loops through 'alt' from all 'img' in the class '_2di5p'
#     for j in followers:
#         b = j.get('alt','')
#         # appends all items in 'alt' to a list called 'captions'
#         captions.append(b)
#     # loops through players
#     for k in players:
#         d[k] = captions
#         if k == k[n]:
#             break
#     n += 1
#
# #     d['LeBron James'] = bron
#
# #     time.sleep(3)
# print(d)
#     # driver.get("https://www.instagram.com/kingjames/")
#
# # Alternatives to Chrome: Firefox, phantomjs

# %% [raw]
# print(captions)

# %% [raw]
# pd.DataFrame.from_dict(d)

# %% [raw]
# for i in new_site:
#     driver.get(i)
#     lenOfPage = driver.execute_script("window.scrollTo(0, document.body.scrollHeight);var lenOfPage=document.body.scrollHeight;return lenOfPage;")
#     match = False
#     while(match==False):
#         lastCount = lenOfPage
#         lenOfPage = driver.execute_script("window.scrollTo(0, document.body.scrollHeight);var lenOfPage=document.body.scrollHeight;return lenOfPage;")
#         if lastCount==lenOfPage:
#             match=True

# %%
chromedriver = "/Users/cyrusrustomji/Downloads/chromedriver-2" # path to the chromedriver executable
os.environ["webdriver.chrome.driver"] = chromedriver
driver = webdriver.Chrome(chromedriver)

# %%
d = {}
# bron = []
for i in new_site:
    driver.get(i)
    lenOfPage = driver.execute_script("window.scrollTo(0, document.body.scrollHeight);var lenOfPage=document.body.scrollHeight;return lenOfPage;")
    match = False
    while(match==False):
        lastCount = lenOfPage
        time.sleep(3)
        lenOfPage = driver.execute_script("window.scrollTo(0, document.body.scrollHeight);var lenOfPage=document.body.scrollHeight;return lenOfPage;")
        if lastCount==lenOfPage:
            match=True
    innerHTML = driver.execute_script("return document.body.innerHTML")
    soup = BeautifulSoup(innerHTML,"lxml")
    
    bron = []
    followers = soup.find_all('img', {'class':'FFVAD'})
    
    for j in followers:
        b = j.get('alt','')
        # the below one liner will remove an emoji
        no_emoji = re.sub(r'[^\w\s,]', ' ', b)
        bron.append(str(no_emoji))
    if len(bron) > 50:
        break
    d[i] = bron
print(d)
# Out:
# {'https://www.instagram.com/kingjames/': ['I seriously can t with  kobebryant  I just wanna enjoy this little bit of sunshine before I m due in Milwaukee tomorrow night and all he wants to talk about is 2 jerseys  8 24      Mamba   Ko8e24RaftersForever  ', 'I can t with this guy  kobebryant  Every time we get together this is all he wants to talk about  8 or 24  I ve been told him both man          TheDebateContinues  Mamba   RaftersForever', 'Stand for something of power and change or don t stand for anything   Equality      StriveForGreatness ', ' Inner self Mr  James please watch your head  Thanks for your concern inner self  but I m going to continue to elevate higher and higher until I jump out the atmosphere   striveforgreatness   welcometoseason15   rwtw ', 'Zoning    SFG   WelcomeToSeason15 ', ' O baby what u got on your feet      Nothing much, just something lite   So modest aren t you         striveforgreatness   welcometoseason15 ', 'Mood    teamswish          ', 'Swag on em then  teamswish          ', 'What he said     IWasABallPlayerToo  IPS  StriveForGreatness  cred  Craig Marks WSL', 'Keep going  Accept nothing less than being great  Anything else is not warranted   striveforgreatness   youngking ', 'This was right after My dog  bossmann99 hit that dagger last night to seal the game   Big time shot my G  Moms was definitely going crazy up above watching the game smiling down on you          striveforgreatness   theland  ', 'Zoning   ', 'They definitely got next and we got the blueprint to get them there   JamesGang   WayofWade    StriveForGreatness  Bronny   Zaire  ', 'The Real reason why I m able to do what I do both on the floor and off it at a very high level   mrs_savannahrj I Thank You       JamesGang   QueenV  ', 'I m a pass first guy still        StriveForGreatness   TheKidFromAkron ', 'Guess we ll call these  The Ejected Game  Soldier 11 colorway               Another great win tonight  We re going Streaking   In my Will Ferrell Old School  voice   StriveForGreatness ', 'Nothin but love from the very start lil bro   Appreciate the       obj and Congrats on the release of these   StriveForGreatness ', 'Yeah it s a  OH  IO thing     ', ' Repost  foxsports    \n kingjames discusses the importance of stories like  89BLOCKS, a  Magnify  documentary from  sportsillustrated and  uninterrupted   89 BLOCKS  premieres today on FOX  Check your local listings ', ' Last night was mad real, fresh out of Advil  Jesus grab the wheel Sheesh    You had to be there to truly  Understand  Even though I wish you were there so u could   VinoChronicles   P S  don t talk to me about wine like u know it if you really don t know what you re talking about  Seriously  Thank you           ', 'I know y all was hoping they lose so u could be all up in  y co  ents that I never read but guess u can t now you probably still will          Anyways S O Urban and the boys on a job well done   OH  GoBucks   StriveForGreatness ', 'My playground    StriveForGreatness ', '       TALk TO  E     Let s Go    OH  IO  StriveForGreatness  Welco eToSeason15', ' TBT  chillwill03 with the end zone hook up   S o to all the boys in green   gold  Keep bringing in the Ws   bring home that title   IrishForever   STATE   StriveForGreatness  Oh and both of them cats got Moss d ', 'Been in my own zone for as long as u can remember and I m here to stay for quite awhile  Hopefully you enjoy it cause I am   KingMe   StriveForGreatness ', 'Just a few good men  And we have more heavy hitters too not pictured   SauceItUp  Kings   BlackExcellence    LiveLaughLove  ', 'What s really going on here man     Like seriously though  Guess she didn t have the RIGHT to finally defend herself huh    GTFOH  Cyntoia should be getting a award, medal of courage of sort instead of being locked up  But not only locked up, convicted as an adult and won t be eligible for parole til 69 years of age   She s 29 now        at the system in place  Doesn t make sense at all especially in this  ...

# %%
for key, value in d.items():
    print(len(value))
# Out:
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 42
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 29
# 28
# 28
# 30
# 30
# 42
# 29
# 30
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12
# 12

# %% [raw]
# d = {}
# captions = []
# for i in new_site:
#     driver.get(i)
#     innerHTML = driver.execute_script("return document.body.innerHTML")
#     soup = BeautifulSoup(innerHTML,"lxml")
#     followers = soup.find_all('img', {'class':'_2di5p'})
#     for j in followers:
#         b = j.get('alt','')
#         # the below one liner will remove an emoji
#         no_emoji = re.sub(r'[^\w\s,]', ' ', b)
#         captions.append(str(no_emoji))
# print(captions)

# %%
d['LeBron James'] = d.pop('https://www.instagram.com/kingjames/')
d['Kevin Durant'] = d.pop('https://www.instagram.com/kevindurant/')
d['Chris Paul'] = d.pop('https://www.instagram.com/cp3/')
d['Paul George'] = d.pop('https://www.instagram.com/ygtrece/')
d['Demarcus Cousins'] = d.pop('https://www.instagram.com/boogiecousins/')
d['Deandre Jordan'] = d.pop('https://www.instagram.com/deandre/')
d['Aaron Gordon'] = d.pop('https://www.instagram.com/original00g/')
d['Julius Randle'] = d.pop('https://www.instagram.com/juliusrandle30/')
d['Jabari Parker'] = d.pop('https://www.instagram.com/jabariparker/')
d['Isaiah Thomas'] = d.pop('https://www.instagram.com/isaiahthomas/')
d['Tyreke Evans'] = d.pop('https://www.instagram.com/rekehavoc1/')
d['Zach Lavine'] = d.pop('https://www.instagram.com/zachlavine8/')
d['Carmelo Anthony'] = d.pop('https://www.instagram.com/carmeloanthony/')
d['Derrick Favors'] = d.pop('https://www.instagram.com/_dfavors15/')
d['Trevor Ariza'] = d.pop('https://www.instagram.com/trevor1ariza/')
d['Enes Kanter'] = d.pop('https://www.instagram.com/eneskanter11/')
d['Will Barton'] = d.pop('https://www.instagram.com/willthethrillb5/')
d['Jusuf Nurkic'] = d.pop('https://www.instagram.com/bosnianbeast27/')
d['Dwyane Wade'] = d.pop('https://www.instagram.com/dwyanewade/')
# d['Marcus Smart'] = d.pop('https://www.instagram.com/younggamechanger/')
d['Brook Lopez'] = d.pop('https://www.instagram.com/brookiethewookie11/')
d['Rodney Hood'] = d.pop('https://www.instagram.com/hoodie5/')
d['Dirk Nowitzki'] = d.pop('https://www.instagram.com/swish41/')
d['Kentavious Caldwell-Pope'] = d.pop('https://www.instagram.com/caldwellpope/')
d['Rajon Rondo'] = d.pop('https://www.instagram.com/rajonrondo/')
d['Kyle Anderson'] = d.pop('https://www.instagram.com/teamslowmo/')
d['Austin Rivers'] = d.pop('https://www.instagram.com/austinjrivers/')
d['Wayne Ellington'] = d.pop('https://www.instagram.com/wayne_elli/')
d['Greg Monroe'] = d.pop('https://www.instagram.com/moosemonroe15/')
d['Fred Van Vleet'] = d.pop('https://www.instagram.com/fredvanvleet/')
d['Luc Mbah A Moute'] = d.pop('https://www.instagram.com/lucmbahamoute/')
d['Michael Beasley'] = d.pop('https://www.instagram.com/michael8easley/')
d['Rudy Gay'] = d.pop('https://www.instagram.com/rudygay/')
d['Wilson Chandler'] = d.pop('https://www.instagram.com/illwil21/')
d['Ersan Ilyasova'] = d.pop('https://www.instagram.com/ersanilyasova7/')
d['Jeremy Lin'] = d.pop('https://www.instagram.com/jlin7/')
d['Milos Teodosic'] = d.pop('https://www.instagram.com/milosteodosic4/')
d['Shabazz Napier'] = d.pop('https://www.instagram.com/shabazznap13r/')
d['Marco Bellinelli'] = d.pop('https://www.instagram.com/mbeli21/')
d['Tony Parker'] = d.pop('https://www.instagram.com/_tonyparker09/')
d['Joe Harris'] = d.pop('https://www.instagram.com/joeharris__12/')
d["Kyle O'Quinn"] = d.pop('https://www.instagram.com/kyle.oquinn/')
d['Dante Exum'] = d.pop('https://www.instagram.com/daanteee/')
d['Lance Stephenson'] = d.pop('https://www.instagram.com/stephensonlance/')
d['Nerlens Noel'] = d.pop('https://www.instagram.com/nerlensnoel3/')
d['Trevor Booker'] = d.pop('https://www.instagram.com/35_fitz/')
d['Jeff Green'] = d.pop('https://www.instagram.com/unclejeffgreen/')
d['Amir Johnson'] = d.pop('https://www.instagram.com/iamamirjohnson/')
d['Ed Davis'] = d.pop('https://www.instagram.com/eddavisxvii/')
d['Danny Green'] = d.pop('https://www.instagram.com/greenranger14/')
d['Mario Hezonja'] = d.pop('https://www.instagram.com/supermariohezonja/')
d['Nemanja Bjelica'] = d.pop('https://www.instagram.com/nemanjabjelica8/')
d['Zaza Pachulia'] = d.pop('https://www.instagram.com/zazapachulia/')
d['Joe Johnson'] = d.pop('https://www.instagram.com/joejohnson247/')
d['Yogi Ferrell'] = d.pop('https://www.instagram.com/yogiferre11/')
d['Seth Curry'] = d.pop('https://www.instagram.com/sdotcurry/')
d['Brandan Wright'] = d.pop('https://www.instagram.com/bkw34/')
d['Doug McDermott'] = d.pop('https://www.instagram.com/dougmcd03/')
d['Clint Capela'] = d.pop('https://www.instagram.com/ccapela15/')
d['Dewayne Dedmon'] = d.pop('https://www.instagram.com/d_dedmon3/')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-62-c75c77f4c979> in <module>()
#      13 d['Carmelo Anthony'] = d.pop('https://www.instagram.com/carmeloanthony/')
#      14 d['Derrick Favors'] = d.pop('https://www.instagram.com/_dfavors15/')
# ---> 15 d['Trevor Ariza'] = d.pop('https://www.instagram.com/trevor1ariza/')
#      16 d['Enes Kanter'] = d.pop('https://www.instagram.com/eneskanter11/')
#      17 d['Will Barton'] = d.pop('https://www.instagram.com/willthethrillb5/')
#
# KeyError: 'https://www.instagram.com/trevor1ariza/'

# %%
df = pd.DataFrame.from_dict(d, orient='index')
df
# Out:
#                                                                                               0   \
# https://www.instagram.com/ccapela15/           THANK YOU for all the support throughout the s...
# https://www.instagram.com/eneskanter11/
# https://www.instagram.com/willthethrillb5/                        going Viral for da Family  PTF
# https://www.instagram.com/bosnianbeast27/      Nije nikome dat bolji dar od sabura  \n ellham...
# https://www.instagram.com/dwyanewade/          Walking into 11 years old like    Happy Birthd...
# https://www.instagram.com/brookiethewookie11/  Just met with our 1st Round Draft Pick out of ...
# https://www.instagram.com/hoodie5/                                  Look at God  Beyond blessed
# https://www.instagram.com/swish41/
# https://www.instagram.com/caldwellpope/        Where to begin with this one   He s been my gu...
# https://www.instagram.com/rajonrondo/             Congrats to the homies       wealreadyknew
# https://www.instagram.com/teamslowmo/                                always got your back X
# https://www.instagram.com/austinjrivers/       My OG  Say what u want about me   but every ye...
# https://www.instagram.com/wayne_elli/                                                        III
# https://www.instagram.com/moosemonroe15/       Wanna know how i maintain, well the secret sta...
# https://www.instagram.com/fredvanvleet/                                      HDMH x  \n mstrooo6
# https://www.instagram.com/lucmbahamoute/       Thank you  Thank you  Thank you       \n\n M12...
# https://www.instagram.com/michael8easley/                                          On my mind
# https://www.instagram.com/rudygay/                                          Yess indeed  newwave
# https://www.instagram.com/illwil21/
# https://www.instagram.com/ersanilyasova7/                                  Happy Mother s Day
# https://www.instagram.com/jlin7/               Back to back  like Jordan 96 97    BuzzCity  t...
# https://www.instagram.com/milosteodosic4/      Slobodna je još samo prva smena, vidimo se na ...
# https://www.instagram.com/shabazznap13r/       Greatness comes at a price and I am willing to...
# https://www.instagram.com/mbeli21/             Amazing experience being in Milan today at  pr...
# https://www.instagram.com/_tonyparker09/         depechemode concert was on     davegahan  spurs
# https://www.instagram.com/joeharris__12/                                            tourdefrance
# https://www.instagram.com/kyle.oquinn/
# https://www.instagram.com/daanteee/            Man , what a year  Glad I was able to battle a...
# https://www.instagram.com/stephensonlance/               I m just trying to make my momma proud
# https://www.instagram.com/nerlensnoel3/                            Let s rock tonight   RnbVoice
# https://www.instagram.com/d_dedmon3/           Congrats bro on 2nd team all rookie  jcollins2...
# https://www.instagram.com/35_fitz/             Happy birthday to the      don t know where I ...
# https://www.instagram.com/unclejeffgreen/      Got to spend more time with  hashtagfostercare...
# https://www.instagram.com/iamamirjohnson/      Happy Birthday Big Sis I love you enjoy your d...
# https://www.instagram.com/eddavisxvii/                                                    Family
# https://www.instagram.com/greenranger14/                                        graduationseason
# https://www.instagram.com/supermariohezonja/                                   magic  supermario
# https://www.instagram.com/nemanjabjelica8/                                  djudju  fandjo  otas
# https://www.instagram.com/zazapachulia/        What a day for Pachulias  Thankful     On to t...
# https://www.instagram.com/joejohnson247/                                             coldblooded
# https://www.instagram.com/yogiferre11/                          All American rings wassss goood
# https://www.instagram.com/sdotcurry/                    todayskicks in honor of the MVP  witness
# https://www.instagram.com/bkw34/                                                    bwood_33 LOL
# https://www.instagram.com/dougmcd03/                                     ChiTownRestaurantSeries
# LeBron James                                   I seriously can t with  kobebryant  I just wan...
# Kevin Durant                                                                              8 v 24
# Chris Paul
# Paul George                                    Happy Mother s Day my love      thank you for ...
# Demarcus Cousins                                TheResurgence wouldn t be right with out some...
# Deandre Jordan                                 Had a great time at the launch of  BlackOps4  ...
# Aaron Gordon
# Julius Randle                                          Work  amoila_cesar         jonathan j lim
# Jabari Parker
# Isaiah Thomas                                                     TBT Back 2 Back Covers  uw_mbb
# Tyreke Evans                                                                         Out of date
# Zach Lavine                                      uptimeenergy  uptimeenergy  howenergyshouldfeel
# Carmelo Anthony                                                 PROUD FATHER Moment     STAYME7O
# Derrick Favors                                 Congrats to my lil bro  b favors2 on his gradu...
#
#                                                                                               1   \
# https://www.instagram.com/ccapela15/           Tout est plus grand au Texas, especially the p...
# https://www.instagram.com/eneskanter11/         Had so much fun \n  Taft High School Chicago ...
# https://www.instagram.com/willthethrillb5/     I don t know her but this is tough  Female lea...
# https://www.instagram.com/bosnianbeast27/      Here we go    RipCityOnTheyAss  PlayoffsOnTheyAss
# https://www.instagram.com/dwyanewade/          Join me this summer for my  celebritysportsaca...
# https://www.instagram.com/brookiethewookie11/      I asked  iamzlatanibrahimovic if I could j...
# https://www.instagram.com/hoodie5/               Good win last night  Gotta keep getting better
# https://www.instagram.com/swish41/
# https://www.instagram.com/caldwellpope/                Link in bio   July 27th going to be fun
# https://www.instagram.com/rajonrondo/                                              essentiawater
# https://www.instagram.com/teamslowmo/                                    Yoooo       ycespedes52
# https://www.instagram.com/austinjrivers/                                 Family is everything
# https://www.instagram.com/wayne_elli/          It wasn t the ending we all wanted but this sm...
# https://www.instagram.com/moosemonroe15/
# https://www.instagram.com/fredvanvleet/                               Reset  Refresh  Recharged
# https://www.instagram.com/lucmbahamoute/       Join me, the Luc Mbah A Moute Foundation and i...
# https://www.instagram.com/michael8easley/      You lie without a mask, thus making you an hon...
# https://www.instagram.com/rudygay/                                           rocboys  ogjuan  MY
# https://www.instagram.com/illwil21/                                               RP  erykahbadu
# https://www.instagram.com/ersanilyasova7/      It was an amazing season   \nThanks to all 76e...
# https://www.instagram.com/jlin7/                     B U Z Z C I T Y  glorytoGod  blessed  smile
# https://www.instagram.com/milosteodosic4/
# https://www.instagram.com/shabazznap13r/                                       from a concrete
# https://www.instagram.com/mbeli21/             Verso gli studi di  skysport con un bodyguard ...
# https://www.instagram.com/_tonyparker09/        4 years old  \nHappy Birthday my sweet Josh
# https://www.instagram.com/joeharris__12/                                            tourdefrance
# https://www.instagram.com/kyle.oquinn/
# https://www.instagram.com/daanteee/                                                  For you
# https://www.instagram.com/stephensonlance/
# https://www.instagram.com/nerlensnoel3/        Little man  KevinHart4Real tried to get on my ...
# https://www.instagram.com/d_dedmon3/           Waking up feeling great to start my week  Appr...
# https://www.instagram.com/35_fitz/             Ruff Rydin  lasvegasrazoradventures  wenotashy...
# https://www.instagram.com/unclejeffgreen/                                    MyMotivation
# https://www.instagram.com/iamamirjohnson/      I know I m a little late but just wanted to sa...
# https://www.instagram.com/eddavisxvii/
# https://www.instagram.com/greenranger14/                         Young Ace   whennaturecalls  DR
# https://www.instagram.com/supermariohezonja/                               super  mario  in  air
# https://www.instagram.com/nemanjabjelica8/     My everything       urija  djudju  fandjo  ulovan
# https://www.instagram.com/zazapachulia/        Back to the finals  \n Blessed  4morewins   du...
# https://www.instagram.com/joejohnson247/                    late nights early mornings     Dip
# https://www.instagram.com/yogiferre11/                                             state champs
# https://www.instagram.com/sdotcurry/                         Melting pot   seem0nayy  wluo1nonly
# https://www.instagram.com/bkw34/                                          Check the hair out
# https://www.instagram.com/dougmcd03/                                          Who s it gonna be
# LeBron James                                   I can t with this guy  kobebryant  Every time ...
# Kevin Durant                                   BTS this week with  AlaskaAir  Got some good t...
# Chris Paul                                     Long flight to DC huh  jharden13  Gotem  USAB2012
# Paul George                                    Happy Mother s Day to my amazing mother  Your ...
# Demarcus Cousins                               TMC   Quote me on this I got a lot more to pro...
# Deandre Jordan                                 My serious face is excited for everyone to pla...
# Aaron Gordon                                    kyrieirving big time shoe, homie  Congrats an...
# Julius Randle
# Jabari Parker                                                                          Brothers
# Isaiah Thomas                                                                           Tacoma
# Tyreke Evans
# Zach Lavine                                     livelovedev getting me right all summer  InTh...
# Carmelo Anthony                                Proud of My New NYC 5th grade AAU team  blacko...
# Derrick Favors
#
#                                                                                               2   \
# https://www.instagram.com/ccapela15/                  Game 78 and still soaring  TunnelVision
# https://www.instagram.com/eneskanter11/          Enes Kanter Summer Basketball Camp Announcem...
# https://www.instagram.com/willthethrillb5/                            Just trying make an impact
# https://www.instagram.com/bosnianbeast27/      Keep working fellas   \n HereWeGo  StillRipCit...
# https://www.instagram.com/dwyanewade/          Fit on point   Swag on infinity   Co pilot on ...
# https://www.instagram.com/brookiethewookie11/
# https://www.instagram.com/hoodie5/             Flip the Page     this chapter gets interestin...
# https://www.instagram.com/swish41/
# https://www.instagram.com/caldwellpope/        WOW   Where do I start  You have been nothing ...
# https://www.instagram.com/rajonrondo/                                                      squad
# https://www.instagram.com/teamslowmo/
# https://www.instagram.com/austinjrivers/                            Young champs    Team M o a M
# https://www.instagram.com/wayne_elli/          At the craps game before tip off   Dragon s sh...
# https://www.instagram.com/moosemonroe15/                       Happy Mothers Day  Love you Silky
# https://www.instagram.com/fredvanvleet/                                    Happy Mother s Day
# https://www.instagram.com/lucmbahamoute/       Mom     You re the best  Thanks for all you do...
# https://www.instagram.com/michael8easley/         nyknicks congrats    brightfuture  respect  wb
# https://www.instagram.com/rudygay/                                               imuptosomething
# https://www.instagram.com/illwil21/            Not a day goes by that I don t appreciate what...
# https://www.instagram.com/ersanilyasova7/      Sizi Seviyorum   TURKIYE         turkey  turki...
# https://www.instagram.com/jlin7/               Fun game  Fun bobblehead night  For teammates ...
# https://www.instagram.com/milosteodosic4/
# https://www.instagram.com/shabazznap13r/                                  the journey continues
# https://www.instagram.com/mbeli21/             Bella chiacchierata con  robertodeponti venerd...
# https://www.instagram.com/_tonyparker09/       Amazing Broadway Musical   \nTime for Playoffs...
# https://www.instagram.com/joeharris__12/                           tourdefrance  ellsworth paris
# https://www.instagram.com/kyle.oquinn/                                                      dloc
# https://www.instagram.com/daanteee/            THANK YOU Jazz fans for the support shown in m...
# https://www.instagram.com/stephensonlance/     Blessings come to those who wait and work hard
# https://www.instagram.com/nerlensnoel3/        I keep my eyes always on the LORD  With him at...
# https://www.instagram.com/d_dedmon3/                                             Good to be home
# https://www.instagram.com/35_fitz/             Got to see lil bro do work professionally for ...
# https://www.instagram.com/unclejeffgreen/      My guy put on an amazing show for  TheLand  MO...
# https://www.instagram.com/iamamirjohnson/
# https://www.instagram.com/eddavisxvii/
# https://www.instagram.com/greenranger14/                  Everybody screaming  GANGGANGGANG   DR
# https://www.instagram.com/supermariohezonja/                     SUPEEER    supermario  magic  8
# https://www.instagram.com/nemanjabjelica8/     Some moments of this season  Thanks Wolves Nat...
# https://www.instagram.com/zazapachulia/        All In  We going to game 7  \n warriors  playo...
# https://www.instagram.com/joejohnson247/                GooseNeck  Holddat  kush  NetsNation
# https://www.instagram.com/yogiferre11/            at bankers life for the luncheon with the team
# https://www.instagram.com/sdotcurry/                                                    poolside
# https://www.instagram.com/bkw34/
# https://www.instagram.com/dougmcd03/           Unfathomably rare grad photo with  doublegfor3...
# LeBron James                                   Stand for something of power and change or don...
# Kevin Durant                                   Don t sleep on the Parking Lot Chronicles  New...
# Chris Paul
# Paul George                                    Happy bday to my amazing princess Pooka butt  ...
# Demarcus Cousins                                 playing chess and the bishop on the muscle  ...
# Deandre Jordan                                                   Love you Avery  Caption this
# Aaron Gordon                                   All in a days work  You see it here first  Sin...
# Julius Randle                                         Bruh at the park looking at shawty like
# Jabari Parker                                            Just because I don t come here often
# Isaiah Thomas                                  Thanks for a dope night  thewebbyawards   for ...
# Tyreke Evans                                             They said I lost it came back on    lol
# Zach Lavine                                                                      All Work is
# Carmelo Anthony                                 The Dream Is  , The Hustle Sold Separately \n...
# Derrick Favors
#
#                                                                                               3   \
# https://www.instagram.com/ccapela15/           T 78 days till the  fifaworldcup     paniniame...
# https://www.instagram.com/eneskanter11/         Take your Racist comments and shove it up you...
# https://www.instagram.com/willthethrillb5/     Right or Wrong you always there for me, Tone, ...
# https://www.instagram.com/bosnianbeast27/      Honored to be able to give some  RipCity fans ...
# https://www.instagram.com/dwyanewade/          Thank you  bookingcom for helping me surprise ...
# https://www.instagram.com/brookiethewookie11/  As we head to halftime, a Patriot and an Eagle...
# https://www.instagram.com/hoodie5/             THANK YOU to Utah for three and a half incredi...
# https://www.instagram.com/swish41/
# https://www.instagram.com/caldwellpope/            Good times at  uninterrupted The Score today
# https://www.instagram.com/rajonrondo/          Always good to be back home  Enjoyed taking th...
# https://www.instagram.com/teamslowmo/           can never sleep till morning on all my quiet ...
# https://www.instagram.com/austinjrivers/       Not exactly the ending we wanted    would love...
# https://www.instagram.com/wayne_elli/          Happy 1st Birthday to the best blessing I coul...
# https://www.instagram.com/moosemonroe15/       Would you switch or change on me if you knew t...
# https://www.instagram.com/fredvanvleet/                                                 Year 2
# https://www.instagram.com/lucmbahamoute/       Luc Mbah A Moute Soccer Charity Game      July...
# https://www.instagram.com/michael8easley/      I hope you love me as much as I love you     w...
# https://www.instagram.com/rudygay/             The  Flight22Classic is back  July 6 8 in Balt...
# https://www.instagram.com/illwil21/            Growing up so fast  Happy 10 J   unconditional...
# https://www.instagram.com/ersanilyasova7/         to          to be continued in round 2  ben...
# https://www.instagram.com/jlin7/               Bobblehead giveaway from the  hornets for the ...
# https://www.instagram.com/milosteodosic4/                                          www teo4 rs
# https://www.instagram.com/shabazznap13r/       Last team standing is what I play for   Nothin...
# https://www.instagram.com/mbeli21/             Oggi ho avuto il previlegio di partecipare all...
# https://www.instagram.com/_tonyparker09/             loyolachicago  finalfour  sanantonio  alamo
# https://www.instagram.com/joeharris__12/        JoeyBuckets T shirts now on sale at www joeha...
# https://www.instagram.com/kyle.oquinn/         Happy Bday to my beautiful and lovely sister  ...
# https://www.instagram.com/daanteee/
# https://www.instagram.com/stephensonlance/     Watching a lot of Larry film this summer    un...
# https://www.instagram.com/nerlensnoel3/                     TSA ain t ready for me    Gameday
# https://www.instagram.com/d_dedmon3/           Season didn t go as planned but wanna thank ev...
# https://www.instagram.com/35_fitz/             Visit Pacers com to bid on these bad boys  All...
# https://www.instagram.com/unclejeffgreen/      Feeling truly humbled  I had the opportunity t...
# https://www.instagram.com/iamamirjohnson/                               HereTheyCome  PhilaUnite
# https://www.instagram.com/eddavisxvii/                            Thanks Shannon  dicksautogroup
# https://www.instagram.com/greenranger14/                                                 details
# https://www.instagram.com/supermariohezonja/            I feel you    germanshepherd  supermario
# https://www.instagram.com/nemanjabjelica8/           Lil bro and big sis          djudju  fandjo
# https://www.instagram.com/zazapachulia/        You have to have a big vision and take very sm...
# https://www.instagram.com/joejohnson247/
# https://www.instagram.com/yogiferre11/                                 me and my boy mo williams
# https://www.instagram.com/sdotcurry/                                    Gotcha back  ianmiller30
# https://www.instagram.com/bkw34/
# https://www.instagram.com/dougmcd03/           Big time thanks to  murphyba23 for the great n...
# LeBron James                                    Inner self Mr  James please watch your head  ...
# Kevin Durant                                               When Klay gets Scorching         dubs
# Chris Paul                                     With the fam   carmeloanthony  bayfrazier  lal...
# Paul George                                     Strength and growth come only through continu...
# Demarcus Cousins                                          it s complimentary to the savages
# Deandre Jordan                                                   Love you Brett  Caption this
# Aaron Gordon                                   3 feet 6 inch vert out of a pool Straight into...
# Julius Randle                                  Everyday we wake up to the happiest kid in the...
# Jabari Parker                                   Stay humble   Being patient  Being gracious  ...
# Isaiah Thomas                                            My Man   TheEqualizer2  CommercialShoot
# Tyreke Evans                                              Can t trick me out my spot  nonotnever
# Zach Lavine                                                                          Clocking in
# Carmelo Anthony                                Happy Mother s Day to the strongest and braves...
# Derrick Favors
#
#                                                                                               4   \
# https://www.instagram.com/ccapela15/           No letting up now  This is DEDICATION   Clutch...
# https://www.instagram.com/eneskanter11/        Is it my defense or just a lucky shot \n     s...
# https://www.instagram.com/willthethrillb5/                                       Unexpected
# https://www.instagram.com/bosnianbeast27/                                      HereWeGo  RipCity
# https://www.instagram.com/dwyanewade/          Swipe     It s getting real in the kitchen wit...
# https://www.instagram.com/brookiethewookie11/  I m a whiz at  photoshop I think it looks just...
# https://www.instagram.com/hoodie5/             Happy birthday to my ride or die, my partner i...
# https://www.instagram.com/swish41/
# https://www.instagram.com/caldwellpope/                                                Junior
# https://www.instagram.com/rajonrondo/          some of the greatest basketball minds I ve eve...
# https://www.instagram.com/teamslowmo/
# https://www.instagram.com/austinjrivers/       No matter what people say, I m going to keep w...
# https://www.instagram.com/wayne_elli/          Love catchin up with my brother   09champs  fa...
# https://www.instagram.com/moosemonroe15/                                       Through the fire
# https://www.instagram.com/fredvanvleet/                                                FVV23 com
# https://www.instagram.com/lucmbahamoute/       Join me, the Luc Mbah A Moute Foundation and i...
# https://www.instagram.com/michael8easley/      Get it done DOT com      wholeteamdot way to p...
# https://www.instagram.com/rudygay/                                      tbt  toysforboysofficial
# https://www.instagram.com/illwil21/                                      On my Lavar Ball
# https://www.instagram.com/ersanilyasova7/      3 1 One more to go W     trusttheprocess  76er...
# https://www.instagram.com/jlin7/               4 in a row   enjoying a couple sandwiches, cla...
# https://www.instagram.com/milosteodosic4/                          Vidimo se na Srebrnom jezeru
# https://www.instagram.com/shabazznap13r/                                        Against All Odds
# https://www.instagram.com/mbeli21/
# https://www.instagram.com/_tonyparker09/       Having fun in Aspen       AllStarBreak  Family...
# https://www.instagram.com/joeharris__12/                                       brooklynnets  nba
# https://www.instagram.com/kyle.oquinn/
# https://www.instagram.com/daanteee/             quick break, now let s get back to work   return
# https://www.instagram.com/stephensonlance/                                               Mi amor
# https://www.instagram.com/nerlensnoel3/         I gave you realness and that s all you gon ge...
# https://www.instagram.com/d_dedmon3/
# https://www.instagram.com/35_fitz/             Surprise Surprise    lil bro had no clue I was...
# https://www.instagram.com/unclejeffgreen/      Happy  InternationalWomensDay to this beauty  ...
# https://www.instagram.com/iamamirjohnson/                                             JOHNSONS
# https://www.instagram.com/eddavisxvii/
# https://www.instagram.com/greenranger14/       Happy bday Brodie, say goodbye to the 20s my g...
# https://www.instagram.com/supermariohezonja/     Thoughts on double sleeve   orlando  supermario
# https://www.instagram.com/nemanjabjelica8/     Great to see  spidadmitchell in Belgrade for  ...
# https://www.instagram.com/zazapachulia/        Looking forward to this amazing  warriorscamp ...
# https://www.instagram.com/joejohnson247/       Just finished a great late nite hoop session  ...
# https://www.instagram.com/yogiferre11/                           I love my team  sectionalchamps
# https://www.instagram.com/sdotcurry/                                            seewhatididthere
# https://www.instagram.com/bkw34/                                               Learn from this
# https://www.instagram.com/dougmcd03/            becauseitsthecup with  btones1   atonino  jen...
# LeBron James                                                  Zoning    SFG   WelcomeToSeason15
# Kevin Durant
# Chris Paul                                                                                  Fire
# Paul George                                                                 Locked in   PlayoffP
# Demarcus Cousins
# Deandre Jordan                                                    Love you Cory  Caption this
# Aaron Gordon                                                         My day 1s  Love these dudes
# Julius Randle                                  There through it all  None of this is possible...
# Jabari Parker                                  You know I had to show love  rapsody  My favor...
# Isaiah Thomas                                  Happy Birthday Chyna, We love and miss you so ...
# Tyreke Evans                                      Her baby u like this outfit  Me I m hungry lol
# Zach Lavine                                                                         threestripes
# Carmelo Anthony                                FROZEN MOMENT   NEW CHAPTER\n JUMPMAN23\n STAY...
# Derrick Favors
#
#                                                                                               5   \
# https://www.instagram.com/ccapela15/           Never forget and never settle  Go gold for the...
# https://www.instagram.com/eneskanter11/                   Hayırlı Ramazanlar   \n  MaklubeKral
# https://www.instagram.com/willthethrillb5/     I ll never give up on me I came out a murder zone
# https://www.instagram.com/bosnianbeast27/                                To the next     RipCity
# https://www.instagram.com/dwyanewade/          Got alil chuckle out of this throwback  gatora...
# https://www.instagram.com/brookiethewookie11/  HS starting five eleven years later  Crazy to ...
# https://www.instagram.com/hoodie5/             It s my lil mans birthday  2 years of pure joy...
# https://www.instagram.com/swish41/             Who s coming out to support Sunday  Link for t...
# https://www.instagram.com/caldwellpope/        Took some time to reflect on my 5th season in ...
# https://www.instagram.com/rajonrondo/          Was a true honor to be in your presence  Frien...
# https://www.instagram.com/teamslowmo/
# https://www.instagram.com/austinjrivers/                                       ittakeseverything
# https://www.instagram.com/wayne_elli/                                          And vice versa
# https://www.instagram.com/moosemonroe15/                                                 Balance
# https://www.instagram.com/fredvanvleet/                                                FVV23 com
# https://www.instagram.com/lucmbahamoute/       Let this Monday be the beginning of the week, ...
# https://www.instagram.com/michael8easley/            More Everything    kyle oquinn  respect  wb
# https://www.instagram.com/rudygay/
# https://www.instagram.com/illwil21/            Manifest the mind to be better  You ll never e...
# https://www.instagram.com/ersanilyasova7/                      Team work make the dream work   W
# https://www.instagram.com/jlin7/               Thanks everyone for participating   The winner...
# https://www.instagram.com/milosteodosic4/                                           www teo4 rs
# https://www.instagram.com/shabazznap13r/                                              No telling
# https://www.instagram.com/mbeli21/                                         Stasera 23 30 su rai1
# https://www.instagram.com/_tonyparker09/       Merry Christmas from my family to yours \nJoye...
# https://www.instagram.com/joeharris__12/
# https://www.instagram.com/kyle.oquinn/         MARCH MADNESS   besttimeoftheyear  beholdthegr...
# https://www.instagram.com/daanteee/                                                       SOON
# https://www.instagram.com/stephensonlance/        Welcome to good burger home of the good burger
# https://www.instagram.com/nerlensnoel3/        Cool summer    I m 23 and I been workin  on me...
# https://www.instagram.com/d_dedmon3/           Gotta give a shoutout to Blue and Bella  natio...
# https://www.instagram.com/35_fitz/             It s that time of year again    My annual camp...
# https://www.instagram.com/unclejeffgreen/      When papa leaves for treatment to the facility...
# https://www.instagram.com/iamamirjohnson/                                A Few Good Men   family
# https://www.instagram.com/eddavisxvii/                            Happy birthday brotha  alllove
# https://www.instagram.com/greenranger14/       Now it s all about the kids  Camp time  Regist...
# https://www.instagram.com/supermariohezonja/                                  SuperMario  monday
# https://www.instagram.com/nemanjabjelica8/     Great to see all the Fener fans at the Adidas ...
# https://www.instagram.com/zazapachulia/                  Western Conference Finals   \nLet s goo
# https://www.instagram.com/joejohnson247/        tonebone318  bri1906 aka thottypippen lmao   ...
# https://www.instagram.com/yogiferre11/                     I swear this is the best orange juice
# https://www.instagram.com/sdotcurry/                     kicksoftheday   I would run to youuuu
# https://www.instagram.com/bkw34/                                                              4
# https://www.instagram.com/dougmcd03/           Gettin better even on off days with  taylorbra...
# LeBron James                                    O baby what u got on your feet      Nothing m...
# Kevin Durant                                                            Lets keep it going my Gs
# Chris Paul                                                                Backyard with the fam
# Paul George                                                            When she fishes too
# Demarcus Cousins
# Deandre Jordan
# Aaron Gordon                                    All smiles mama   I Love you  happy Mothers Day
# Julius Randle
# Jabari Parker                                   Picket lines and picket signs, Don t punish m...
# Isaiah Thomas                                  Happy Birthday to my beautiful Mom  teti46  En...
# Tyreke Evans                                                                           savage up
# Zach Lavine                                    Love u Mom  Not just today but everyday is you...
# Carmelo Anthony                                Happiness is to be found within your own life,...
# Derrick Favors
#
#                                                                                               6   \
# https://www.instagram.com/ccapela15/                     Want something  Go get it    Houston
# https://www.instagram.com/eneskanter11/         Trying to change it up little bit for the sum...
# https://www.instagram.com/willthethrillb5/     I made it by not letting em tell me who i was ...
# https://www.instagram.com/bosnianbeast27/                                                RipCity
# https://www.instagram.com/dwyanewade/           Swipe Hamper basketball has become our after ...
# https://www.instagram.com/brookiethewookie11/  Escaped the Room tonight in Milwaukee   Shouto...
# https://www.instagram.com/hoodie5/             You never know where life will take you   Swip...
# https://www.instagram.com/swish41/
# https://www.instagram.com/caldwellpope/         kjrookieyear was a blast  Can t believe this ...
# https://www.instagram.com/rajonrondo/                                               hat game bih
# https://www.instagram.com/teamslowmo/
# https://www.instagram.com/austinjrivers/               Keep em coming  \n clipsnation  teamdepth
# https://www.instagram.com/wayne_elli/          Enjoyed being a part of  nbaallstarweekend 201...
# https://www.instagram.com/moosemonroe15/       Happy Gday to da       thefamily u kno what it...
# https://www.instagram.com/fredvanvleet/                                                      B Y
# https://www.instagram.com/lucmbahamoute/       Il y a tant de bonheur dans un brin de muguet ...
# https://www.instagram.com/michael8easley/      Reintroduced to people I been introduced      ...
# https://www.instagram.com/rudygay/             It was a long season  A lot of emotions  A lot...
# https://www.instagram.com/illwil21/                Either build or destroy  Where you come from
# https://www.instagram.com/ersanilyasova7/            Game1W  nbaplayoffs  trusttheprocess  76ers
# https://www.instagram.com/jlin7/               Love this squad     kembaschainsdestroymine  t...
# https://www.instagram.com/milosteodosic4/                                          Srećan Uskrs
# https://www.instagram.com/shabazznap13r/                   When you find it send me the address
# https://www.instagram.com/mbeli21/             Ci vediamo stasera su rai1 alle 23 30 a CHE FU...
# https://www.instagram.com/_tonyparker09/       Loving this snow in  SanAntonio       snow  ch...
# https://www.instagram.com/joeharris__12/
# https://www.instagram.com/kyle.oquinn/                                              tommyzweibel
# https://www.instagram.com/daanteee/                                                    Everyday
# https://www.instagram.com/stephensonlance/                                             Love
# https://www.instagram.com/nerlensnoel3/
# https://www.instagram.com/d_dedmon3/           Appreciate y all for showing out  Family first...
# https://www.instagram.com/35_fitz/                            Until next time Indy  kaidenstrong
# https://www.instagram.com/unclejeffgreen/                                                  Trust
# https://www.instagram.com/iamamirjohnson/                        Shakuump       filayyyy Voice
# https://www.instagram.com/eddavisxvii/
# https://www.instagram.com/greenranger14/       Was a rough one, but a helluva ride with guys ...
# https://www.instagram.com/supermariohezonja/                              Χρόνια πολλά ΘΡΥΛΕ
# https://www.instagram.com/nemanjabjelica8/     Best part of off season is chilling with my so...
# https://www.instagram.com/zazapachulia/                    Start the week right   \nPlayoffs2018
# https://www.instagram.com/joejohnson247/                                  Ok I m a lil bored now
# https://www.instagram.com/yogiferre11/                                                   whippin
# https://www.instagram.com/sdotcurry/                                                Dorm coolin
# https://www.instagram.com/bkw34/
# https://www.instagram.com/dougmcd03/                                                    Da Bulls
# LeBron James                                                         Mood    teamswish
# Kevin Durant                                                                         Whole lotta
# Chris Paul                                                        Headed for morning workouts
# Paul George                                                4 13 18 Happy Mamba Day  kobebryant
# Demarcus Cousins                                 I serve and I Hussle under any condition  \n...
# Deandre Jordan                                                         i m wired up   hol  up
# Aaron Gordon                                         Livin day to day\n ty_jackson94 photo cred
# Julius Randle                                       Some work with my brother  tylerrelph10
# Jabari Parker                                  Blessed to have  joeysredhots provide food for...
# Isaiah Thomas                                  One of the few guys I m waaaaaaay taller than ...
# Tyreke Evans                                                                       Drip or drown
# Zach Lavine                                                                 Big Kids sometimes
# Carmelo Anthony                                 The  DreamStillLives  What s yours   \n  STAY...
# Derrick Favors
#
#                                                                                               7   \
# https://www.instagram.com/ccapela15/           Had a great time shooting with  att, check it ...
# https://www.instagram.com/eneskanter11/         Happy Birthday to my brother  willyhernangome...
# https://www.instagram.com/willthethrillb5/                I be so icy I might as well try hockey
# https://www.instagram.com/bosnianbeast27/      First thing accomplished   ToTheNextOne  RipCi...
# https://www.instagram.com/dwyanewade/          You want it for yourself but you want it for y...
# https://www.instagram.com/brookiethewookie11/
# https://www.instagram.com/hoodie5/                                    Was a trip to remember
# https://www.instagram.com/swish41/
# https://www.instagram.com/caldwellpope/        My little man turns 1 today  I remember the da...
# https://www.instagram.com/rajonrondo/                             always with me\n essentiawater
# https://www.instagram.com/teamslowmo/                                         tbt westwood days
# https://www.instagram.com/austinjrivers/                          Close to getting back at it
# https://www.instagram.com/wayne_elli/                             Ran in to the OG   TarHeeltalk
# https://www.instagram.com/moosemonroe15/       See, it s a cold world, so homie bundle up\nWe...
# https://www.instagram.com/fredvanvleet/        Prayers to the families and those effected by ...
# https://www.instagram.com/lucmbahamoute/       Happy Friday  Forget about all the bad things ...
# https://www.instagram.com/michael8easley/                        Wishing you well    ronbaker620
# https://www.instagram.com/rudygay/             When you get a win  promotorsports and your ou...
# https://www.instagram.com/illwil21/
# https://www.instagram.com/ersanilyasova7/                               HereTheyCome  PhilaUnite
# https://www.instagram.com/jlin7/               the flow was real last night lol  spenceneedle...
# https://www.instagram.com/milosteodosic4/                                          www teo4 rs
# https://www.instagram.com/shabazznap13r/         We too old for this    you not changing in 2018
# https://www.instagram.com/mbeli21/
# https://www.instagram.com/_tonyparker09/       Repost  tjparker5 \nTP is back   Hardwork pays...
# https://www.instagram.com/joeharris__12/        Repost  brooklynnets    \nWishing  aliceharri...
# https://www.instagram.com/kyle.oquinn/
# https://www.instagram.com/daanteee/            Had a blast playing   CODWWII with  bensimmons...
# https://www.instagram.com/stephensonlance/                                          Be great
# https://www.instagram.com/nerlensnoel3/                                  Cool it Now   Espys2017
# https://www.instagram.com/d_dedmon3/                                       Back at it  justwatch
# https://www.instagram.com/35_fitz/             Man, where do I start  Definitely the most cha...
# https://www.instagram.com/unclejeffgreen/      Since  All Met in high school to now 10 yrs in...
# https://www.instagram.com/iamamirjohnson/                                        Big AJ x Lil AJ
# https://www.instagram.com/eddavisxvii/
# https://www.instagram.com/greenranger14/                                        FEARNOMAN  Game5
# https://www.instagram.com/supermariohezonja/
# https://www.instagram.com/nemanjabjelica8/     We fought and worked hard, but it couldn t be ...
# https://www.instagram.com/zazapachulia/
# https://www.instagram.com/joejohnson247/       Myself,  bri1906    tonebone318 on set of The ...
# https://www.instagram.com/yogiferre11/                                   my dinner for the night
# https://www.instagram.com/sdotcurry/                        My llittle sis and some bum lol
# https://www.instagram.com/bkw34/
# https://www.instagram.com/dougmcd03/                                                         Chi
# LeBron James                                                Swag on em then  teamswish
# Kevin Durant                                                               1  7    3  5  \n dubs
# Chris Paul                                     My most BEAUTIFUL wife  jada_ap at her baby sh...
# Paul George                                                         Great night to fish Oklahoma
# Demarcus Cousins
# Deandre Jordan                                 great seeing my brother the legend last night ...
# Aaron Gordon                                                                       Aaron Addison
# Julius Randle                                  Congrats to The Troutt family and Winstar Farm...
# Jabari Parker                                  Big thank you to  bucks partner  cousinssubs f...
# Isaiah Thomas                                  Damn     1 yr ago today I got the worse news I...
# Tyreke Evans                                                             allgasnobreaks
# Zach Lavine                                    Late nights and early mornings WORK\n\n samlim...
# Carmelo Anthony                                The  IAmMLKJr documentary catch it tonight 9 8...
# Derrick Favors
#
#                                                                                               8   \
# https://www.instagram.com/ccapela15/                                 BE SOMEONE  HoustonKnows
# https://www.instagram.com/eneskanter11/         One of the 2 coolest dudes around  direalshag...
# https://www.instagram.com/willthethrillb5/                          Originals From Time  CA  PTF
# https://www.instagram.com/bosnianbeast27/      Ma nek , neka padaje cuskije \nneka me sevdah ...
# https://www.instagram.com/dwyanewade/           Swipe Picture 1  When I thought it was a good...
# https://www.instagram.com/brookiethewookie11/  Heard the Mayor of Albuquerque is making the D...
# ...
# https://www.instagram.com/michael8easley/                                                   None
# https://www.instagram.com/rudygay/                                                          None
# https://www.instagram.com/illwil21/                                                         None
# https://www.instagram.com/ersanilyasova7/                                                   None
# https://www.instagram.com/jlin7/               time flies     excited to start my 6th season ...
# https://www.instagram.com/milosteodosic4/                                                   None
# https://www.instagram.com/shabazznap13r/                                                    None
# https://www.instagram.com/mbeli21/                                                          None
# https://www.instagram.com/_tonyparker09/                                                    None
# https://www.instagram.com/joeharris__12/                                                    None
# https://www.instagram.com/kyle.oquinn/                                                      None
# https://www.instagram.com/daanteee/                                                         None
# https://www.instagram.com/stephensonlance/                                                  None
# https://www.instagram.com/nerlensnoel3/                                                     None
# https://www.instagram.com/d_dedmon3/                                                        None
# https://www.instagram.com/35_fitz/                                                          None
# https://www.instagram.com/unclejeffgreen/                                                   None
# https://www.instagram.com/iamamirjohnson/                                                   None
# https://www.instagram.com/eddavisxvii/                                                      None
# https://www.instagram.com/greenranger14/                                                    None
# https://www.instagram.com/supermariohezonja/                                                None
# https://www.instagram.com/nemanjabjelica8/                                                  None
# https://www.instagram.com/zazapachulia/                                                     None
# https://www.instagram.com/joejohnson247/                                                    None
# https://www.instagram.com/yogiferre11/                                                      None
# https://www.instagram.com/sdotcurry/                                                        None
# https://www.instagram.com/bkw34/                                                            None
# https://www.instagram.com/dougmcd03/                                                        None
# LeBron James                                    LongLiveTheKing   StriveForGreatness   Savage...
# Kevin Durant                                                                                None
# Chris Paul                                                                                  None
# Paul George                                                                                 None
# Demarcus Cousins                                                                            None
# Deandre Jordan                                                                              None
# Aaron Gordon                                                                                None
# Julius Randle                                                                               None
# Jabari Parker                                                                               None
# Isaiah Thomas                                                                               None
# Tyreke Evans                                                                                None
# Zach Lavine                                                                                 None
# Carmelo Anthony                                                                             None
# Derrick Favors                                                                              None
#
#                                                                                               40  \
# https://www.instagram.com/ccapela15/                                                        None
# https://www.instagram.com/eneskanter11/                                                     None
# https://www.instagram.com/willthethrillb5/                                                  None
# https://www.instagram.com/bosnianbeast27/                                                   None
# https://www.instagram.com/dwyanewade/                                                       None
# https://www.instagram.com/brookiethewookie11/                                               None
# https://www.instagram.com/hoodie5/                                                          None
# https://www.instagram.com/swish41/                                                          None
# https://www.instagram.com/caldwellpope/                                                     None
# https://www.instagram.com/rajonrondo/                                                       None
# https://www.instagram.com/teamslowmo/                                                       None
# https://www.instagram.com/austinjrivers/                                                    None
# https://www.instagram.com/wayne_elli/                                                       None
# https://www.instagram.com/moosemonroe15/                                                    None
# https://www.instagram.com/fredvanvleet/                                                     None
# https://www.instagram.com/lucmbahamoute/                                                    None
# https://www.instagram.com/michael8easley/                                                   None
# https://www.instagram.com/rudygay/                                                          None
# https://www.instagram.com/illwil21/                                                         None
# https://www.instagram.com/ersanilyasova7/                                                   None
# https://www.instagram.com/jlin7/               Watchin the Panthers game with  hairston_pj  _...
# https://www.instagram.com/milosteodosic4/                                                   None
# https://www.instagram.com/shabazznap13r/                                                    None
# https://www.instagram.com/mbeli21/                                                          None
# https://www.instagram.com/_tonyparker09/                                                    None
# https://www.instagram.com/joeharris__12/                                                    None
# https://www.instagram.com/kyle.oquinn/                                                      None
# https://www.instagram.com/daanteee/                                                         None
# https://www.instagram.com/stephensonlance/                                                  None
# https://www.instagram.com/nerlensnoel3/                                                     None
# https://www.instagram.com/d_dedmon3/                                                        None
# https://www.instagram.com/35_fitz/                                                          None
# https://www.instagram.com/unclejeffgreen/                                                   None
# https://www.instagram.com/iamamirjohnson/                                                   None
# https://www.instagram.com/eddavisxvii/                                                      None
# https://www.instagram.com/greenranger14/                                                    None
# https://www.instagram.com/supermariohezonja/                                                None
# https://www.instagram.com/nemanjabjelica8/                                                  None
# https://www.instagram.com/zazapachulia/                                                     None
# https://www.instagram.com/joejohnson247/                                                    None
# https://www.instagram.com/yogiferre11/                                                      None
# https://www.instagram.com/sdotcurry/                                                        None
# https://www.instagram.com/bkw34/                                                            None
# https://www.instagram.com/dougmcd03/                                                        None
# LeBron James                                   Man o man Chef D ain t messing around tonight ...
# Kevin Durant                                                                                None
# Chris Paul                                                                                  None
# Paul George                                                                                 None
# Demarcus Cousins                                                                            None
# Deandre Jordan                                                                              None
# Aaron Gordon                                                                                None
# Julius Randle                                                                               None
# Jabari Parker                                                                               None
# Isaiah Thomas                                                                               None
# Tyreke Evans                                                                                None
# Zach Lavine                                                                                 None
# Carmelo Anthony                                                                             None
# Derrick Favors                                                                              None
#
#                                                                                               41
# https://www.instagram.com/ccapela15/                                                        None
# https://www.instagram.com/eneskanter11/                                                     None
# https://www.instagram.com/willthethrillb5/                                                  None
# https://www.instagram.com/bosnianbeast27/                                                   None
# https://www.instagram.com/dwyanewade/                                                       None
# https://www.instagram.com/brookiethewookie11/                                               None
# https://www.instagram.com/hoodie5/                                                          None
# https://www.instagram.com/swish41/                                                          None
# https://www.instagram.com/caldwellpope/                                                     None
# https://www.instagram.com/rajonrondo/                                                       None
# https://www.instagram.com/teamslowmo/                                                       None
# https://www.instagram.com/austinjrivers/                                                    None
# https://www.instagram.com/wayne_elli/                                                       None
# https://www.instagram.com/moosemonroe15/                                                    None
# https://www.instagram.com/fredvanvleet/                                                     None
# https://www.instagram.com/lucmbahamoute/                                                    None
# https://www.instagram.com/michael8easley/                                                   None
# https://www.instagram.com/rudygay/                                                          None
# https://www.instagram.com/illwil21/                                                         None
# https://www.instagram.com/ersanilyasova7/                                                   None
# https://www.instagram.com/jlin7/               Grubbin at a hole in the wall diner in middle ...
# https://www.instagram.com/milosteodosic4/                                                   None
# https://www.instagram.com/shabazznap13r/                                                    None
# https://www.instagram.com/mbeli21/                                                          None
# https://www.instagram.com/_tonyparker09/                                                    None
# https://www.instagram.com/joeharris__12/                                                    None
# https://www.instagram.com/kyle.oquinn/                                                      None
# https://www.instagram.com/daanteee/                                                         None
# https://www.instagram.com/stephensonlance/                                                  None
# https://www.instagram.com/nerlensnoel3/                                                     None
# https://www.instagram.com/d_dedmon3/                                                        None
# https://www.instagram.com/35_fitz/                                                          None
# https://www.instagram.com/unclejeffgreen/                                                   None
# https://www.instagram.com/iamamirjohnson/                                                   None
# https://www.instagram.com/eddavisxvii/                                                      None
# https://www.instagram.com/greenranger14/                                                    None
# https://www.instagram.com/supermariohezonja/                                                None
# https://www.instagram.com/nemanjabjelica8/                                                  None
# https://www.instagram.com/zazapachulia/                                                     None
# https://www.instagram.com/joejohnson247/                                                    None
# https://www.instagram.com/yogiferre11/                                                      None
# https://www.instagram.com/sdotcurry/                                                        None
# https://www.instagram.com/bkw34/                                                            None
# https://www.instagram.com/dougmcd03/                                                        None
# LeBron James                                   When the mask came off I was still in characte...
# Kevin Durant                                                                                None
# Chris Paul                                                                                  None
# Paul George                                                                                 None
# Demarcus Cousins                                                                            None
# Deandre Jordan                                                                              None
# Aaron Gordon                                                                                None
# Julius Randle                                                                               None
# Jabari Parker                                                                               None
# Isaiah Thomas                                                                               None
# Tyreke Evans                                                                                None
# Zach Lavine                                                                                 None
# Carmelo Anthony                                                                             None
# Derrick Favors                                                                              None
#
# [58 rows x 42 columns]

# %% [raw]
# with open('insta_captions.pkl', 'wb') as handle:
#     pickle.dump(captions, handle, protocol=pickle.HIGHEST_PROTOCOL)
