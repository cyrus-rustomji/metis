# %% [markdown]
# # Imports

# %%
# pip install selenium 
# download chromedriver: https://sites.google.com/a/chromium.org/chromedriver/downloads      

from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup
import pickle
import time
import os
import requests
import re
import pandas as pd
import csv
import pandas as pd
import emoji

# %% [markdown]
# # Data Cleaning

# %%
# put insta handles of free agent ballers into a list
columns = ['insta_handles']
data = pd.read_csv('/Users/cyrusrustomji/Documents/metis/personal_metis/passion_projects/bball_4/Data/insta_handles.csv',names=columns)
insta = data.insta_handles.tolist()
insta
# Out:
# ['kingjames',
#  'kevindurant',
#  'cp3',
#  'ygtrece',
#  'boogiecousins',
#  'ccapela15',
#  'deandre',
#  'original00g',
#  'juliusrandle30',
#  'jabariparker',
#  'isaiahthomas',
#  'rekehavoc1',
#  'zachlavine8',
#  'carmeloantony',
#  '_dfavors15',
#  'trevor1ariza',
#  'eneskanter11',
#  'willthethrillb5',
#  'bosnianbeast27',
#  'dwyanewade',
#  'younggamechanger',
#  'brookiethewookie11',
#  'hoodie5',
#  'swish41',
#  'caldwellpope',
#  'rajonrondo',
#  'teamslowmo',
#  'austinjrivers',
#  'wayne_elli',
#  'moosemonroe15',
#  'fredvanvleet',
#  'lucmbahmoute',
#  'michael8easley',
#  'rudygay',
#  'illwil21',
#  'ersanilyasova7',
#  'jlin7',
#  'milosteodosic4',
#  'shabazznap13r',
#  'mbeli21',
#  '_tonyparker09',
#  'joeharris_12',
#  'kyle.oquinn',
#  'daanteee',
#  'stephensonlance',
#  'nerlensnoel3',
#  'd_dedmon3',
#  '35_fitz',
#  'unclejeffgreen',
#  'iamamirjohnson',
#  'eddavisxvii',
#  'greenranger14',
#  'supermariohezonja',
#  'nemanjabjelica8',
#  'zazapachulia',
#  'joejohnson247',
#  'yogiferre11',
#  'sdotcurry',
#  'bkw34',
#  'dougmcd03']

# %%
# put insta handles of free agent ballers into a list
columns3 = ['players_names']
data3 = pd.read_csv('/Users/cyrusrustomji/Documents/metis/personal_metis/passion_projects/bball_4/Data/players_names.csv',names=columns3)
players2 = data3.players_names.tolist()
players2
# Out:
# ['Lebron James',
#  'Kevin Durant',
#  'Chris Paul',
#  'Paul George',
#  'Demarcus Cousins',
#  'Clint Capela',
#  'Deandre Jordan',
#  'Aaron Gordon',
#  'Julius Randle',
#  'Jabari Parker',
#  'Isaiah Thomas',
#  'Tyreke Evans',
#  'Zach Lavine',
#  'Carmelo Anthony',
#  'Derrick Favors',
#  'Trevor Ariza',
#  'Enes Kanter',
#  'Will Barton',
#  'Jusuf Nurkic',
#  'Dwyane Wade',
#  'Marcus Smart',
#  'Brook Lopez',
#  'Rodney Hood',
#  'Dirk Nowitzki',
#  'Kentavious Caldwell-Pope',
#  'Rajon Rondo',
#  'Kyle Anderson',
#  'Austin Rivers',
#  'Wayne Ellington',
#  'Greg Monroe',
#  'Fred Van Vleet',
#  'Luc Mbah A Moute',
#  'Michael Beasley',
#  'Rudy Gay',
#  'Wilson Chandler',
#  'Ersan Ilyasova',
#  'Jeremy Lin',
#  'Milos Teodosic',
#  'Shabazz Napier',
#  'Marco Bellinelli',
#  'Tony Parker',
#  'Joe Harris',
#  "Kyle O'Quinn",
#  'Dante Exum',
#  'Lance Stephenson',
#  'Nerlens Noel',
#  'Dewayne Dedmon',
#  'Trevor Booker',
#  'Jeff Green',
#  'Amir Johnson',
#  'Ed Davis',
#  'Danny Green',
#  'Mario Hezonja',
#  'Nemanja Bjelica',
#  'Zaza Pachulia',
#  'Joe Johnson',
#  'Yogi Ferrell',
#  'Seth Curry',
#  'Brandan Wright',
#  'Doug McDermott']

# %%
# put insta handles of free agent ballers into a list
columns2 = ['players_names']
data2 = pd.read_csv('/Users/cyrusrustomji/Documents/metis/personal_metis/passion_projects/bball_4/Data/players_names.csv',names=columns2)
players = data2.players_names.tolist()
players
# Out:
# ['Lebron James',
#  'Kevin Durant',
#  'Chris Paul',
#  'Paul George',
#  'Demarcus Cousins',
#  'Clint Capela',
#  'Deandre Jordan',
#  'Aaron Gordon',
#  'Julius Randle',
#  'Jabari Parker',
#  'Isaiah Thomas',
#  'Tyreke Evans',
#  'Zach Lavine',
#  'Carmelo Anthony',
#  'Derrick Favors',
#  'Trevor Ariza',
#  'Enes Kanter',
#  'Will Barton',
#  'Jusuf Nurkic',
#  'Dwyane Wade',
#  'Marcus Smart',
#  'Brook Lopez',
#  'Rodney Hood',
#  'Dirk Nowitzki',
#  'Kentavious Caldwell-Pope',
#  'Rajon Rondo',
#  'Kyle Anderson',
#  'Austin Rivers',
#  'Wayne Ellington',
#  'Greg Monroe',
#  'Fred Van Vleet',
#  'Luc Mbah A Moute',
#  'Michael Beasley',
#  'Rudy Gay',
#  'Wilson Chandler',
#  'Ersan Ilyasova',
#  'Jeremy Lin',
#  'Milos Teodosic',
#  'Shabazz Napier',
#  'Marco Bellinelli',
#  'Tony Parker',
#  'Joe Harris',
#  "Kyle O'Quinn",
#  'Dante Exum',
#  'Lance Stephenson',
#  'Nerlens Noel',
#  'Dewayne Dedmon',
#  'Trevor Booker',
#  'Jeff Green',
#  'Amir Johnson',
#  'Ed Davis',
#  'Danny Green',
#  'Mario Hezonja',
#  'Nemanja Bjelica',
#  'Zaza Pachulia',
#  'Joe Johnson',
#  'Yogi Ferrell',
#  'Seth Curry',
#  'Brandan Wright',
#  'Doug McDermott']

# %%
# put instagram links of ballers into a list

site = "https://www.instagram.com/"
new_site = []
for i in insta:
    new_site.append(site + i + '/')
print(new_site)
# Out:
# ['https://www.instagram.com/kingjames/', 'https://www.instagram.com/kevindurant/', 'https://www.instagram.com/cp3/', 'https://www.instagram.com/ygtrece/', 'https://www.instagram.com/boogiecousins/', 'https://www.instagram.com/ccapela15/', 'https://www.instagram.com/deandre/', 'https://www.instagram.com/original00g/', 'https://www.instagram.com/juliusrandle30/', 'https://www.instagram.com/jabariparker/', 'https://www.instagram.com/isaiahthomas/', 'https://www.instagram.com/rekehavoc1/', 'https://www.instagram.com/zachlavine8/', 'https://www.instagram.com/carmeloantony/', 'https://www.instagram.com/_dfavors15/', 'https://www.instagram.com/trevor1ariza/', 'https://www.instagram.com/eneskanter11/', 'https://www.instagram.com/willthethrillb5/', 'https://www.instagram.com/bosnianbeast27/', 'https://www.instagram.com/dwyanewade/', 'https://www.instagram.com/younggamechanger/', 'https://www.instagram.com/brookiethewookie11/', 'https://www.instagram.com/hoodie5/', 'https://www.instagram.com/swish41/', 'https://www.instagram.com/caldwellpope/', 'https://www.instagram.com/rajonrondo/', 'https://www.instagram.com/teamslowmo/', 'https://www.instagram.com/austinjrivers/', 'https://www.instagram.com/wayne_elli/', 'https://www.instagram.com/moosemonroe15/', 'https://www.instagram.com/fredvanvleet/', 'https://www.instagram.com/lucmbahmoute/', 'https://www.instagram.com/michael8easley/', 'https://www.instagram.com/rudygay/', 'https://www.instagram.com/illwil21/', 'https://www.instagram.com/ersanilyasova7/', 'https://www.instagram.com/jlin7/', 'https://www.instagram.com/milosteodosic4/', 'https://www.instagram.com/shabazznap13r/', 'https://www.instagram.com/mbeli21/', 'https://www.instagram.com/_tonyparker09/', 'https://www.instagram.com/joeharris_12/', 'https://www.instagram.com/kyle.oquinn/', 'https://www.instagram.com/daanteee/', 'https://www.instagram.com/stephensonlance/', 'https://www.instagram.com/nerlensnoel3/', 'https://www.instagram.com/d_dedmon3/', 'https://www.instagram.com/35_fitz/', 'https://www.instagram.com/unclejeffgreen/', 'https://www.instagram.com/iamamirjohnson/', 'https://www.instagram.com/eddavisxvii/', 'https://www.instagram.com/greenranger14/', 'https://www.instagram.com/supermariohezonja/', 'https://www.instagram.com/nemanjabjelica8/', 'https://www.instagram.com/zazapachulia/', 'https://www.instagram.com/joejohnson247/', 'https://www.instagram.com/yogiferre11/', 'https://www.instagram.com/sdotcurry/', 'https://www.instagram.com/bkw34/', 'https://www.instagram.com/dougmcd03/']

# %%
chromedriver = "/Users/cyrusrustomji/Downloads/chromedriver-2" # path to the chromedriver executable
os.environ["webdriver.chrome.driver"] = chromedriver
driver = webdriver.Chrome(chromedriver)

# %% [raw]
# d = {}
# p = 0
# captions = []
# for i in new_site:
#     driver.get(i)
#     innerHTML = driver.execute_script("return document.body.innerHTML")
#     soup = BeautifulSoup(innerHTML,"lxml")
# #     lenOfPage = driver.execute_script("window.scrollTo(0, document.body.scrollHeight);var lenOfPage=document.body.scrollHeight;return lenOfPage;")
# #     match = False
# #     while(match==False):
# #         lastCount = lenOfPage
# #         time.sleep(3)
# #         lenOfPage = driver.execute_script("window.scrollTo(0, document.body.scrollHeight);var lenOfPage=document.body.scrollHeight;return lenOfPage;")
# #         if lastCount==lenOfPage:
# #             match=True
#     # finds all '_2di5p' classes
#     followers = soup.find_all('img', {'class':'_2di5p'})
#     n = 0
#     # loops through 'alt' from all 'img' in the class '_2di5p'
#     for j in followers:
#         b = j.get('alt','')
#         # appends all items in 'alt' to a list called 'captions'
#         captions.append(b)
#     # loops through players
#     for k in players:
#         d[k] = captions
#         if k == k[n]:
#             break
#     n += 1
#
# #     d['LeBron James'] = bron
#
# #     time.sleep(3)
# print(d)
#     # driver.get("https://www.instagram.com/kingjames/")
#
# # Alternatives to Chrome: Firefox, phantomjs

# %% [raw]
# print(captions)

# %% [raw]
# pd.DataFrame.from_dict(d)

# %%
d = {}
for i in new_site:
    driver.get(i)
    innerHTML = driver.execute_script("return document.body.innerHTML")
    soup = BeautifulSoup(innerHTML,"lxml")
    bron = []
    followers = soup.find_all('img', {'class':'_2di5p'})
    for j in followers:
        b = j.get('alt','')
        bron.append(b)
        res = ''.join(bron)
    d[i] = res
print(d)

# emoji_pattern = re.compile("["
#         u"\U0001F600-\U0001F64F"  # emoticons
#         u"\U0001F300-\U0001F5FF"  # symbols & pictographs
#         u"\U0001F680"  # transport & map symbols
#                            "]+", flags=re.UNICODE)
# for j in bron:
#     lebron = emoji_pattern.sub(r'',j)
#     james.append(lebron)
# Out:
# {'https://www.instagram.com/kingjames/': '“Life’s most persistent and urgent question is, ‘What are you doing for others?’” – MLK 🤝 IG Stories will be used on this page as a platform for people bringing light to this world. #AlwaysBelieveZero Dark Thirty-23 Mode is about to commence. I’m going dark so others can be the light. Watch this space. Peace.\n#AlwaysBelieve ✊🏾👑My Princess Z👸🏽 wasn’t messing around about getting outside today! Told her she better get as much as she can cause it maybe 20 below 0 tomorrow! 🤣😞🤦🏾\u200d♂️!!! #DaddysLilAngel👼🏽 #IAintRockingwitThatFaceThoughSheMadeThough. 🤣🤣🤣🤣🤣🤣🤣🤣🤣Before I go dark tomorrow night I wanted to leave you with some more #LEBRONWATCH Fire 🔥🔥🔥🔥🔥🔥\nThis was one of my favorite colorways from this season so wanted to make sure you guys have a chance to get them. Stay tuned- Summer’18 #LetsGo #striveforgreatness🚀 #thekidfromakron🤴🏾 #jamesgang👑 #rwtw🏅Well they say it’s a first time for everything huh?!?! Guess so in this case. 82/82 in my 15th season. Just wanna be available to my teammates as much as I can throughout a long season as well as keep my mind and body as fresh as it can be too! #SFG🚀 #RWTW🏅 #JamesGang👑  #ThekidfromAKRON🤴🏾Reds!! 🔴🔴🔴 Get that semi-final W!! @liverpoolfc 🏆 #SFG🚀 #LFC⚽Up up and away!!! Let’s continue to travel to parts unknown. #Season15 #SFG🚀 #JamesGang👑Walk with me! We’re all Kings and Queens!!!! 🤴🏾👸🏾. “I’m King” #StriveforGreatness🚀 #RWTW🏅KING JAMES X FRESH PRINCE 👑 👑 #FamilyTies #Klutch #RWTWAnother 1 in my @djkhaled voice! 🤦🏾\u200d♂️🤷🏾\u200d♂️. They did get that W over us though. #Season15 #striveforgreatness🚀 #jamesgang👑 #thekidfromakron🤴🏾Last night I had no choice but to go back to where it all started for me in 2003 with the Air Zoom Generation #LeBronWatch. Felt like I was actually back in the original while on the floor. Crazy! #striveforgreatness🚀 #jamesgang👑 #thekidfromakron🤴🏾 #rwtw🏅 #fabfive✊🏾🤣🤣Wit my heavy hitta aka The Queen 👸🏽 post game last night! We ride and die together #JamesGang👑', 'https://www.instagram.com/kevindurant/': 'Thanks for having us at #BrainstormHealth @ariannahuff @fortunemag @richkleimanHappy steph year, 30 clipThat’s how it’s done! 🙏🏾🙏🏾Was an honor to be a judge at the @bgcp Youth of the Year awards this week. Congrats to Alysia! #TeamBGCPThe Durant Company has invested in @Overtime, gonna do more videos soon with them for you guys on my YouTube channel...stay tunedSolid D. Better O. \nAs a 19 year old rook Kobe inspired me. I Still feel the same 10 years later. Love to 24 and 8, nobody like him!! #mambaout.......8 v 24BTS this week with @AlaskaAir. Got some good things coming...video up soonDon’t sleep on the Parking Lot Chronicles! New episode up on my Youtube channel now @javalemcgee @richkleiman #thirtyfivemediaWhen Klay gets Scorching....... #dubs🌀Lets keep it going my Gs', 'https://www.instagram.com/cp3/': "Prayers to the kids and families affected by today's tragedy. We need to do better by our children. #BiggerThanBasketballStay The Course #RedNation 🤘🏾Last night’s rotation 👀🔥The power of focus and persistence is real!! Congrats Andre Ingram on your NBA debut. Well deserved!National Sibling Day!Masters Champ!!! Congrats @preedgolf!Roadtrip ready. Thank you @hookandalbert 🙏🏾Family BusinessBack like we’re in '07🤘🏾My dream is that all kids have access to the same resources and grow up in a world full of opportunities. #DreamStillLives #MLK50Not a bad way for me and my guy to do our first Final Four together!! Big Thank You to the Brunson family and way to hoop @jalenbrunson1 ✊🏾#FinalFour #MarchMadness#ad In partnership with @nbacares and @statefarm, we opened the new library at C.E. King Middle school, providing hundreds of students with the resources they need to succeed. Find out how you can make a difference at NeighborhoodOfGood.com (link in bio) #HereToHelp #HoustonStrong", 'https://www.instagram.com/ygtrece/': 'Happy Mother’s Day my love ❤️😘🤗 thank you for all that you do for our kids and I. So thankful for the bea ...

# %%
df = pd.DataFrame.from_dict(d, orient='index')
df
# Out:
#                                                                                                0
# https://www.instagram.com/kingjames/           “Life’s most persistent and urgent question is...
# https://www.instagram.com/kevindurant/         Thanks for having us at #BrainstormHealth @ari...
# https://www.instagram.com/cp3/                 Prayers to the kids and families affected by t...
# https://www.instagram.com/ygtrece/             Happy Mother’s Day my love ❤️😘🤗 thank you for ...
# https://www.instagram.com/boogiecousins/       TMC “ Quote me on this I got a lot more to pro...
# https://www.instagram.com/ccapela15/           Tout est plus grand au Texas, especially the p...
# https://www.instagram.com/deandre/             Had a great time at the launch of #BlackOps4. ...
# https://www.instagram.com/original00g/         @kyrieirving big time shoe, homie! Congrats an...
# https://www.instagram.com/juliusrandle30/      Work @amoila_cesar 🎥 🎥 🎥: @jonathan.j.limBruh ...
# https://www.instagram.com/jabariparker/        Brothers.Just because I don't come here often....
# https://www.instagram.com/isaiahthomas/        #TBT Back 2 Back Covers @uw_mbb#Tacoma 🏁Thanks...
# https://www.instagram.com/rekehavoc1/          Out of date🏊🏾‍♂️💦They said I lost it came back...
# https://www.instagram.com/zachlavine8/         All Work is....Clocking in#threestripesLove u ...
# https://www.instagram.com/carmeloantony/
# https://www.instagram.com/_dfavors15/          Congrats to my lil bro @b.favors2 on his gradu...
# https://www.instagram.com/trevor1ariza/        We got it!🚀🚀🚀Game day! Let’s do it!🚀🚀🚀👀🚀@nike ...
# https://www.instagram.com/eneskanter11/        ‪Trying to change it up little bit for the sum...
# https://www.instagram.com/willthethrillb5/     going Viral for da Family #PTFI don’t know her...
# https://www.instagram.com/bosnianbeast27/      Nije nikome dat bolji dar od sabura. \n#ellham...
# https://www.instagram.com/dwyanewade/          Join me this summer for my @celebritysportsaca...
# https://www.instagram.com/younggamechanger/    Join me this summer for my @celebritysportsaca...
# https://www.instagram.com/brookiethewookie11/  Just met with our 1st Round Draft Pick out of ...
# https://www.instagram.com/hoodie5/             Good win last night! Gotta keep getting better...
# https://www.instagram.com/swish41/             Who's coming out to support Sunday? Link for t...
# https://www.instagram.com/caldwellpope/        Link in bio!! July 27th going to be fun!!WOW!!...
# https://www.instagram.com/rajonrondo/          Congrats to the homies ✊🏾✊🏾 #wealreadyknew👆🏾👆🏾...
# https://www.instagram.com/teamslowmo/          always got your back X ❤️❤️Yoooo!!!!! @ycesped...
# https://www.instagram.com/austinjrivers/       My OG. Say what u want about me...but every ye...
# https://www.instagram.com/wayne_elli/          IIIIt wasn’t the ending we all wanted but this...
# https://www.instagram.com/moosemonroe15/       Wanna know how i maintain, well the secret sta...
# https://www.instagram.com/fredvanvleet/        #HDMH x 💰\n@mstrooo6Reset. Refresh. Recharged....
# https://www.instagram.com/lucmbahmoute/        #HDMH x 💰\n@mstrooo6Reset. Refresh. Recharged....
# https://www.instagram.com/michael8easley/      On my mind...You lie without a mask, thus maki...
# https://www.instagram.com/rudygay/             #rocboys #ogjuan #MY🤫 #imuptosomethingThe #Fli...
# https://www.instagram.com/illwil21/            RP @erykahbaduNot a day goes by that I don’t a...
# https://www.instagram.com/ersanilyasova7/      Happy Mother’s Day 😘🌹It was an amazing season!...
# https://www.instagram.com/jlin7/               我自己畫了薯條🍟因為我很喜歡吃哈哈! @jj_lin 怎麼樣？你們覺得還可以嗎？Drew s...
# https://www.instagram.com/milosteodosic4/      Slobodna je još samo prva smena, vidimo se na ...
# https://www.instagram.com/shabazznap13r/       & the journey continues.Last team standing is ...
# https://www.instagram.com/mbeli21/             Verso gli studi di @skysport con un bodyguard ...
# https://www.instagram.com/_tonyparker09/       @depechemode concert is on 🔥🤘🏼#davegahan #spur...
# https://www.instagram.com/joeharris_12/        @depechemode concert is on 🔥🤘🏼#davegahan #spur...
# https://www.instagram.com/kyle.oquinn/         🔬♠️ 🇨🇦🦐 📸: @dlocHappy Bday to my beautiful and...
# https://www.instagram.com/daanteee/            Man , what a year. Glad I was able to battle a...
# https://www.instagram.com/stephensonlance/     I’m just trying to make my momma proud @2chain...
# https://www.instagram.com/nerlensnoel3/        Let’s rock tonight! #RnbVoiceLittle man @Kevin...
# https://www.instagram.com/d_dedmon3/           Congrats bro on 2nd team all rookie @jcollins2...
# https://www.instagram.com/35_fitz/             Ruff Rydin #lasvegasrazoradventures #wenotashy...
# https://www.instagram.com/unclejeffgreen/      Got to spend more time with @hashtagfostercare...
# https://www.instagram.com/iamamirjohnson/      Happy Birthday Big Sis I love you enjoy your d...
# https://www.instagram.com/eddavisxvii/         FamilyThanks Shannon #dicksautogroupHappy birt...
# https://www.instagram.com/greenranger14/       #graduationseasonYoung Ace! #whennaturecalls #...
# https://www.instagram.com/supermariohezonja/   #magic #supermario#super #mario #in #airSUPEEE...
# https://www.instagram.com/nemanjabjelica8/     🤟🏻 #djudju #fandjo #otasMy everything !👫❤️ #ur...
# https://www.instagram.com/zazapachulia/        All In. We going to game 7. \n#warriors #playo...
# https://www.instagram.com/joejohnson247/       These old pics brings back so many great! Memo...
# https://www.instagram.com/yogiferre11/         oh is that what we on.....ima stay over here 😁...
# https://www.instagram.com/sdotcurry/           #TBT \nThe beginning of my journey.. Hardworki...
# https://www.instagram.com/bkw34/               Congratulations @coachpenny1 👍🏽Football Sunday...
# https://www.instagram.com/dougmcd03/           Happy 26th 🤔Birthday @eneskanter11 ! Enjoy you...

# %% [raw]
# with open('insta.pkl', 'wb') as handle:
#     pickle.dump(df, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
with open('all_one_df.pkl', 'wb') as handle:
    pickle.dump(df, handle, protocol=pickle.HIGHEST_PROTOCOL)
