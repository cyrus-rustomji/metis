# %% [markdown]
# # Imports

# %%
import csv
import pandas as pd
import numpy as np
import ast
from sqlalchemy import create_engine
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Import Yelp Data

# %%
business = pd.read_csv('/Users/cyrusrustomji/Downloads/yelp_business.csv')[['business_id','name','address','city','state','postal_code','stars','review_count','is_open','categories']]
hours = pd.read_csv('/Users/cyrusrustomji/Downloads/yelp_business_hours.csv')
business.head()
# Out:
#               business_id                        name  \
# 0  FYWN1wneV18bWNgQjJ2GNg          "Dental by Design"
# 1  He-G7vWjzVUysIKrfNbPUQ       "Stephen Szabo Salon"
# 2  KQPW8lFf1y5BT2MxiSZ3QA     "Western Motor Vehicle"
# 3  8DShNS-LuFqpEWIp0HxijA          "Sports Authority"
# 4  PfOCPjBrlQAnz__NXj9h_w  "Brick House Tavern + Tap"
#
#                             address            city state postal_code  stars  \
# 0        "4855 E Warner Rd, Ste B9"       Ahwatukee    AZ       85044    4.0
# 1              "3101 Washington Rd"        McMurray    PA       15317    3.0
# 2          "6025 N 27th Ave, Ste 1"         Phoenix    AZ       85017    1.5
# 3  "5000 Arizona Mills Cr, Ste 435"           Tempe    AZ       85282    3.0
# 4                    "581 Howe Ave"  Cuyahoga Falls    OH       44221    3.5
#
#    review_count  is_open                                         categories
# 0            22        1  Dentists;General Dentistry;Health & Medical;Or...
# 1            11        1  Hair Stylists;Hair Salons;Men's Hair Salons;Bl...
# 2            18        1  Departments of Motor Vehicles;Public Services ...
# 3             9        0                            Sporting Goods;Shopping
# 4           116        1  American (New);Nightlife;Bars;Sandwiches;Ameri...

# %%
# use toronto because in vegas people eat out
business.city.value_counts().head()
# Out:
# Las Vegas     26775
# Phoenix       17213
# Toronto       17206
# Charlotte      8553
# Scottsdale     8228
# Name: city, dtype: int64

# %%
business = business[business.city == 'Toronto']
# combine = business.merge(hours, left_on='business_id', right_on='business_id', how='left')

# %%
toronto = pd.read_csv('../Data/y_business.csv')
# toronto = toronto.drop(columns=['open','close'])
toronto.head()
# Out:
#               business_id               name neighborhood  \
# 0  VnibgMdZkBqnMDnY4BWPUg   "Naan and Kabob"  Scarborough
# 1  T0ju0drMLfXJPNLnEsEYgw  "Pizza Hot Wings"  Scarborough
# 2  VtQIAj8eXvHqc_8MtMMGwg   "Afghan Cuisine"          NaN
# 3  tQKRXnzWZllD4M3toa-UaQ     "Taftan Kebab"   Willowdale
# 4  d2k0I5mbDiOYrCAjJLLMiQ      "Mazar Kabob"    Etobicoke
#
#                            address     city state postal_code   latitude  \
# 0              "1780 Markham Road"  Toronto    ON     M1B 2W2  43.795206
# 1         "3007 Sheppard Avenue E"  Toronto    ON     M1T 3J5  43.776407
# 2  "66 Overlea Boulevard, Unit 62"  Toronto    ON     M4H 1C4  43.708070
# 3              "5372 Yonge Street"  Toronto    ON     M2N 5R5  43.774496
# 4      "133 The West Mall, Unit 1"  Toronto    ON         M9C  43.619813
#
#    longitude  stars  review_count  is_open  \
# 0 -79.239781    4.0            12        1
# 1 -79.318135    3.5             3        0
# 2 -79.341508    4.0            30        1
# 3 -79.414301    3.0            41        1
# 4 -79.561822    4.5             9        1
#
#                                                final
# 0  ["Afghan","Halal","Middle Eastern","Restaurant...
# 1  ["Afghan","Halal","Pizza","Restaurants","","",...
# 2  ["Afghan","Persian/Iranian","Halal","Restauran...
# 3  ["Afghan","Persian/Iranian","Middle Eastern","...
# 4  ["Afghan","Restaurants","","","","","","","","...

# %% [markdown]
# # Clean Yelp Data

# %%
toronto['categories'] = toronto['final']

# %%
# make items in the categories column a list instead of a string
i = 0
for y in toronto.categories:
    if type(y) == str:
        toronto.categories[i] = ast.literal_eval(y)
    i +=1
# Out:
# /Users/cyrusrustomji/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
# put all categories in a list

lst = []
categories = []
for j in toronto.categories:
    for x in j:
        lst.append(x)
for item in lst:
    if item not in categories:
        categories.append(item)
categories
# Out:
# ['Organic Stores',
#  'Food',
#  'Health Markets',
#  'Specialty Food',
#  '',
#  'Meat Shops',
#  'Grocery',
#  'OrganicStores',
#  'Juice Bars & Smoothies',
#  'Specialty Schools',
#  'Caterers',
#  'Event Planning & Services',
#  'Cooking Schools',
#  'Party&EventPlanning',
#  'Education',
#  'Beer',
#  'Wine & Spirits',
#  'Bars',
#  'Nightlife',
#  'Ice Cream & Frozen Yogurt',
#  'Bakeries',
#  'Gluten-Free',
#  'Restaurants',
#  'Cafes',
#  'Desserts',
#  'Breakfast & Brunch',
#  'Coffee & Tea',
#  'Chinese',
#  'Russian',
#  'Ukrainian',
#  'Caribbean',
#  'German',
#  'WineTours',
#  'Hotels & Travel',
#  'Wineries',
#  'Arts & Entertainment',
#  'Tours',
#  'Butcher',
#  'Sporting Goods',
#  'Bikes',
#  'Shopping',
#  'LocalServices',
#  'BikeRepair/Maintenance',
#  'Sandwiches',
#  'SeafoodMarkets',
#  'Chicken Wings',
#  'Southern',
#  'Fast Food',
#  'Middle Eastern',
#  'Venezuelan',
#  'Latin American',
#  'Delis',
#  'Salad',
#  'Live/RawFood',
#  'Modern European',
#  'Pizza',
#  'Korean',
#  'Asian Fusion',
#  'Diners',
#  'American',
#  'Kosher',
#  'Seafood',
#  'Mediterranean',
#  'Coffee & Tea Supplies',
#  'Food Stands',
#  'Indian',
#  'Italian',
#  'Cocktail Bars',
#  'HookahBars',
#  'Local Flavor',
#  'YelpEvents',
#  'Barbeque',
#  'Halal',
#  'Comfort Food',
#  'Chicken Shop',
#  'Herbs & Spices',
#  'Food Trucks',
#  'Greek',
#  'Vegan',
#  'FinancialServices',
#  'Investing',
#  'Lawyers',
#  'BankruptcyLaw',
#  'ProfessionalServices',
#  'Portuguese',
#  'FarmersMarket',
#  'Street Vendors',
#  'Soup',
#  'SushiBars',
#  'Japanese',
#  'Steakhouses',
#  'Cajun/Creole',
#  'Swimwear',
#  'Fashion',
#  'Lingerie',
#  'Canadian',
#  'Music Venues',
#  'Burgers',
#  'Brazilian',
#  'Supernatural Readings',
#  'Astrologers',
#  'LifeCoach',
#  'Distilleries',
#  'Lounges',
#  'Sushi Bars',
#  'CustomCakes',
#  'Food Delivery Services',
#  'Bagels',
#  'Child Care & Day Care',
#  'Moroccan',
#  'CheeseShops',
#  'Carpet Cleaning',
#  'Chocolatiers & Shops',
#  'Patisserie/CakeShop',
#  'Imported Food',
#  'Ethnic Food',
#  'SriLankan',
#  'ShoeStores',
#  'Turkish',
#  'Afghan',
#  'African',
#  'Tea Rooms',
#  'Ethiopian',
#  'SportsWear',
#  'OutdoorGear',
#  'CandyStores',
#  'Tapas Bars',
#  'Mexican',
#  'Sports Wear',
#  'ScreenPrinting',
#  'CustomizedMerchandise',
#  'Graphic Design',
#  'WeddingPlanning',
#  'Peruvian',
#  'SpecialtySchools',
#  'Vegetarian',
#  'Venues & Event Spaces',
#  'TravelServices',
#  'Beer Bar',
#  'Wine Bars',
#  'Arabian',
#  'Noodles',
#  'GiftShops',
#  'Flowers & Gifts',
#  'Florists',
#  'PrintingServices',
#  'Couriers & Delivery Services',
#  'Coffee Roasteries',
#  'Kebab',
#  'Fruits & Veggies',
#  'Vietnamese',
#  'Pubs',
#  'French',
#  'Bed&Breakfast',
#  'Hotels',
#  'TapasBars',
#  'PrivateTutors',
#  'MusicalInstruments&Teachers',
#  'Musicians',
#  'Funeral Services & Cemeteries',
#  'CremationServices',
#  'Taiwanese',
#  'Yelp Events',
#  'Gold Buyers',
#  'Jewelry',
#  'PawnShops',
#  'VapeShops',
#  'PersonalChefs',
#  'Convenience Stores',
#  'Beauty&Spas',
#  'Seafood Markets',
#  'Internet Cafes',
#  'Lebanese',
#  'Wine Tours',
#  'WalkingTours',
#  'Food Tours',
#  'Cheese Shops',
#  'Persian/Iranian',
#  'Thai',
#  'Bubble Tea',
#  'Tapas/Small Plates',
#  'Formal Wear',
#  'Bridal',
#  'Bistros',
#  'Cheesesteaks',
#  'Fish & Chips',
#  'HotPot',
#  'Preschools',
#  'Breweries',
#  'Soul Food',
#  'Delicatessen',
#  'DimSum',
#  'Pakistani',
#  'Spanish',
#  'Gastropubs',
#  'Do-It-YourselfFood',
#  'Canadian ',
#  'Salvadoran',
#  'Himalayan/Nepalese',
#  'Creperies',
#  'Churches',
#  'ReligiousOrganizations',
#  'Poutineries',
#  'Donairs',
#  'Recording & Rehearsal Studios',
#  'Ramen',
#  'ToyStores',
#  'PartySupplies',
#  'Whiskey Bars',
#  'Filipino',
#  'Kombucha',
#  'Polish',
#  'Food Court',
#  'TobaccoShops',
#  'Waffles',
#  'Cantonese',
#  'Malaysian',
#  'Czech',
#  'CommunityService/Non-Profit',
#  'Team Building Activities',
#  'Dim Sum',
#  'Event Photography',
#  'Photographers',
#  'SessionPhotography',
#  'Do-It-Yourself Food',
#  'Ethical Grocery',
#  'International Grocery',
#  'Falafel',
#  'Currency Exchange',
#  'HotDogs',
#  'PhotographyStores&Services',
#  'HobbyShops',
#  'Donuts',
#  "Women'sClothing",
#  'British',
#  'PersonalShopping',
#  'Bangladeshi',
#  'Nicaraguan',
#  'Hungarian',
#  'VacationRentals',
#  'Guest Houses',
#  'Hot Dogs',
#  'Sri Lankan',
#  'Arcades',
#  'Bartenders',
#  'South African',
#  'Australian',
#  'Poke',
#  'Hawaiian',
#  'Live/Raw Food',
#  'Belgian',
#  'Argentine',
#  'DiscountStore',
#  'Sports Bars',
#  'DrivingSchools',
#  'Performing Arts',
#  'Dance Schools',
#  'TestPreparation',
#  'LanguageSchools',
#  'Cabaret',
#  'CosmetologySchools',
#  'DaySpas',
#  'ArtSchools',
#  'Colombian',
#  'Syrian',
#  'Tex-Mex',
#  'Antiques',
#  'International',
#  'Scandinavian',
#  'Cuban',
#  'Dive Bars',
#  'Buffets',
#  'Indonesian',
#  'Wholesale Stores',
#  'Brewing Supplies',
#  'Casinos',
#  'PoolHalls',
#  'Smokehouse',
#  'SkinCare',
#  'Luggage',
#  'LeatherGoods',
#  'Passport&VisaServices',
#  'Macarons',
#  'ChampagneBars',
#  'Jazz & Blues',
#  'HomeServices',
#  'Plumbing',
#  'Wraps',
#  'ShavedSnow',
#  'Cosmetics&BeautySupply',
#  'Farmers Market',
#  'Laotian',
#  'EthicalGrocery',
#  'Irish',
#  'EthnicGrocery',
#  'Pop-up Shops',
#  'Hakka',
#  'GayBars',
#  'Personal Chefs',
#  "Men'sClothing",
#  'Iberian',
#  'IrishPub',
#  'Patisserie/Cake Shop',
#  'ShoppingCenters',
#  'Brasseries',
#  'AirportLounges',
#  'HealthRetreats',
#  'Hot Pot',
#  'Massage',
#  'Brewpubs',
#  'Cambodian',
#  'Stadiums & Arenas',
#  'Pop-upShops',
#  'TikiBars',
#  'Izakaya',
#  'Scottish',
#  'Egyptian',
#  'DinnerTheater',
#  'Discount Store',
#  'Candy Stores',
#  'Opera & Ballet',
#  'Gelato',
#  'Pet Services',
#  'Museums',
#  'Pets',
#  'PetTraining',
#  'PetStores',
#  'Customized Merchandise',
#  'Custom Cakes',
#  'ShippingCenters',
#  'Austrian',
#  'Pretzels',
#  'HeadShops',
#  'Wigs',
#  'Electronics',
#  'Karaoke',
#  'Psychics',
#  'Tiki Bars',
#  'MassageSchools',
#  'Colleges&Universities',
#  'Mongolian',
#  'Hainan',
#  'Fondue',
#  'Udon',
#  'WebDesign',
#  'Marketing',
#  'Shanghainese',
#  'Basque',
#  'Slovakian',
#  'Singaporean',
#  'Ethnic Grocery',
#  'Czech/Slovakian',
#  'Drugstores',
#  'Criminal Defense Law',
#  'ImmigrationLaw',
#  'Divorce&FamilyLaw',
#  'LegalServices',
#  'Cupcakes',
#  'Reunion',
#  'Cideries',
#  'SouthAfrican',
#  'PanAsian',
#  'Art Galleries',
#  "Children's Clothing",
#  'Check Cashing/Pay-day Loans',
#  'Szechuan',
#  'TabletopGames',
#  'WholesaleStores',
#  'Irish Pub',
#  'PublicServices&Government',
#  'Landmarks&HistoricalBuildings',
#  'DepartmentStores',
#  'BeerGardens',
#  'PastaShops',
#  'Burmese',
#  'ThemedCafes',
#  'Minho',
#  'Ticket Sales',
#  'Real Estate Law',
#  'EstatePlanningLaw',
#  'Notaries',
#  'PersonalInjuryLaw',
#  'Furniture Reupholstery',
#  'ThriftStores',
#  'AnimalShelters',
#  'BespokeClothing',
#  'Pan Asian',
#  'HairSalons',
#  'Screen Printing',
#  'Speakeasies',
#  'Hostels',
#  'Pawn Shops',
#  'BeerHall',
#  'Cafeteria',
#  'Banks&CreditUnions',
#  'Middle Schools & High Schools',
#  'ElementarySchools']

# %% [raw]
# df = pd.DataFrame(categories)
# df.head()
# df.to_csv('toronto_categories.csv',index=False, header=False)

# %%
# put stars in a lst

five = 0
four_five = 0
four = 0
three_five = 0
three = 0
two_five = 0
two = 0
one_five = 0
one = 0
lst = []
for x in toronto.stars:
    if x == 5.0:
        five += 1
    if x == 4.5:
        four_five += 1
    if x == 4:
        four += 1
    if x == 3.5:
        three_five += 1
    if x == 3.0:
        three += 1
    if x == 2.5:
        two_five += 1
    if x == 2.0:
        two += 1
    if x == 1.5:
        one_five += 1
    if x == 1:
        one += 1
lst.append(five)
lst.append(four_five)
lst.append(four)
lst.append(three_five)
lst.append(three)
lst.append(two_five)
lst.append(two)
lst.append(one_five)
lst.append(one)
lst
# Out:
# [261, 1002, 2268, 2421, 1859, 887, 443, 163, 45]

# %%
# stars vs count of stars

df_stars = pd.DataFrame({'Stars': lst,'Count of Stars': toronto.stars.unique()})
df_stars
# Out:
#    Stars  Count of Stars
# 0    261             4.0
# 1   1002             3.5
# 2   2268             3.0
# 3   2421             4.5
# 4   1859             5.0
# 5    887             2.5
# 6    443             2.0
# 7    163             1.5
# 8     45             1.0

# %%
# create a dataframe for only 5 star restaurants

most_stars = toronto.drop(columns=['business_id','neighborhood','address','city','state','postal_code','latitude','longitude','is_open','final'])
most_stars = most_stars.sort_values(by=['stars','review_count'],ascending=False)
most_stars = most_stars[most_stars.stars == 5.0]
most_stars
# Out:
#                                          name  stars  review_count  \
# 4417                          "Baretto Caffe"    5.0           187
# 8805       "New Orleans Seafood & Steakhouse"    5.0            68
# 3739              "Kozlik's Canadian Mustard"    5.0            64
# 9185                                 "Veghed"    5.0            48
# 925                            "Zeal Burgers"    5.0            41
# 4983                          "Yelp Gets Lit"    5.0            41
# 139   "Teta's Mediterranean Kitchen & Bakery"    5.0            38
# 2504                     "Wild North Flowers"    5.0            34
# 1022                       "Wallace Espresso"    5.0            33
# 4834                      "Salus Fresh Foods"    5.0            33
# 4113                      "Peter's No Frills"    5.0            32
# 3504                                "Bar Ape"    5.0            31
# 7442                         "Barista & Chef"    5.0            29
# 9347                 "The 2016 Yelpie Awards"    5.0            29
# 2050                         "Volta Espresso"    5.0            24
# 5242                            "Bar Sybanne"    5.0            21
# 3059                       "Oakwood Espresso"    5.0            20
# 7317                                "T-Sushi"    5.0            20
# 7573         "Arabesque Middle Eastern Foods"    5.0            20
# 1745             "Gloria Espresso Bar & Cafe"    5.0            19
# 1342                       "Amore Fine Foods"    5.0            18
# 8279                        "Village Juicery"    5.0            18
# 4558                           "Pasta Pantry"    5.0            17
# 7143                     "La Sala Restaurant"    5.0            17
# 8643              "East of York Gourmet Food"    5.0            17
# 1075                            "Rick's Cafe"    5.0            16
# 1677         "COCO Crafted Organic Chocolate"    5.0            16
# 2330                    "M&J's Eastside Deli"    5.0            15
# 3546         "Grinning Face Non-Dairy Gelato"    5.0            15
# 4984             "Brewhaha At Bandit Brewery"    5.0            15
# ...                                       ...    ...           ...
# 4115                      "Rosedale's Finest"    5.0             3
# 4226                         "Baskin Robbins"    5.0             3
# 4844                        "Antioch Kitchen"    5.0             3
# 5040                        "Caprae & Suidae"    5.0             3
# 5050               "Superior Sausage Company"    5.0             3
# 5236                "The Windmill Restaurant"    5.0             3
# 5449                        "Horizons Lounge"    5.0             3
# 5504                            "Loch & Quay"    5.0             3
# 5583                            "Good Cheese"    5.0             3
# 5619                           "Jal Gua Cafe"    5.0             3
# 5983                            "Xamar Weyne"    5.0             3
# 6145            "Brasileirissimo Steak House"    5.0             3
# 6147                        "Sunnyside Grill"    5.0             3
# 6342                              "Starbucks"    5.0             3
# 6521              "Popeyes Louisiana Kitchen"    5.0             3
# 6686                 "Brando's Fried Chicken"    5.0             3
# 7162                   "Lupara Kitchen Table"    5.0             3
# 7455        "Cactus Sandwiches & BBQ chicken"    5.0             3
# 7744                           "Sicily Pizza"    5.0             3
# 7920              "Orca  The Sandwich Shoppe"    5.0             3
# 8186                                   "Cleo"    5.0             3
# 8205         "Pomarosa Coffee Shop & Kitchen"    5.0             3
# 8356                             "Pita Break"    5.0             3
# 8505                       "Caribbean Bistro"    5.0             3
# 8705                           "Elle Cuisine"    5.0             3
# 8744                    "Canuck Sports Stuff"    5.0             3
# 8754                    "Cardinal Skate Shop"    5.0             3
# 8831    "Tara Greene Tarot Psychic Astrology"    5.0             3
# 8889                    "John's Sushi Bistro"    5.0             3
# 8940                         "Broad Lingerie"    5.0             3
#
#                                              categories
# 4417  [Italian, Cafes, Restaurants, , , , , , , , , ...
# 8805  [Steakhouses, Cajun/Creole, Seafood, Restauran...
# 3739   [Food, Specialty Food, , , , , , , , , , , , , ]
# 9185  [Vegan, Vegetarian, Restaurants, , , , , , , ,...
# 925    [Burgers, Restaurants, , , , , , , , , , , , , ]
# 4983  [Local Flavor, YelpEvents, , , , , , , , , , ,...
# 139   [Arabian, Mediterranean, Bakeries, Middle East...
# 2504  [Event Planning & Services, Shopping, Florists...
# 1022  [Cafes, Food, Restaurants, Coffee & Tea, , , ,...
# 4834  [Juice Bars & Smoothies, Salad, Food, Restaura...
# 4113  [Grocery, SeafoodMarkets, Food, Bakeries, Spec...
# 3504  [Food, Ice Cream & Frozen Yogurt, , , , , , , ...
# 7442  [Restaurants, Mediterranean, , , , , , , , , ,...
# 9347  [Yelp Events, Local Flavor, , , , , , , , , , ...
# 2050  [Coffee & Tea, Restaurants, Cafes, Food, , , ,...
# 5242  [Middle Eastern, Moroccan, Mediterranean, Rest...
# 3059     [Food, Coffee & Tea, , , , , , , , , , , , , ]
# 7317  [Restaurants, Japanese, Food Delivery Services...
# 7573  [Restaurants, Middle Eastern, , , , , , , , , ...
# 1745  [Coffee & Tea, Cafes, Food, Restaurants, , , ,...
# 1342  [Caterers, Event Planning & Services, Restaura...
# 8279  [Salad, Live/RawFood, Specialty Food, Restaura...
# 4558  [Italian, Restaurants, Grocery, Specialty Food...
# 7143   [Restaurants, Italian, , , , , , , , , , , , , ]
# 8643  [Specialty Food, Food, Indian, Sandwiches, Res...
# 1075     [Cafes, Restaurants, , , , , , , , , , , , , ]
# 1677  [Chocolatiers & Shops, Food, Specialty Food, ,...
# 2330  [Diners, Breakfast & Brunch, Restaurants, Sand...
# 3546  [Food, Ice Cream & Frozen Yogurt, Desserts, Sp...
# 4984  [Local Flavor, YelpEvents, , , , , , , , , , ,...
# ...                                                 ...
# 4115  [Grocery, Specialty Food, Desserts, Food, Coff...
# 4226  [Ice Cream & Frozen Yogurt, Food, , , , , , , ...
# 4844  [Kebab, Restaurants, Middle Eastern, Turkish, ...
# 5040  [Meat Shops, Food, Specialty Food, Butcher, , ...
# 5050  [Meat Shops, Specialty Food, Food, , , , , , ,...
# 5236  [Middle Eastern, Mediterranean, Restaurants, ,...
# 5449  [Nightlife, Cafes, Restaurants, Bars, HookahBa...
# 5504  [Nightlife, Juice Bars & Smoothies, Restaurant...
# 5583  [Nightlife, Specialty Food, Bars, Beer Bar, Fo...
# 5619  [Organic Stores, Breakfast & Brunch, Food, Caf...
# 5983   [Restaurants, African, , , , , , , , , , , , , ]
# 6145  [Restaurants, Brazilian, Portuguese, , , , , ,...
# 6147  [Restaurants, Breakfast & Brunch, , , , , , , ...
# 6342  [Restaurants, Cafes, Coffee & Tea, Food, , , ,...
# 6521  [Restaurants, Chicken Wings, Southern, Fast Fo...
# 6686  [Restaurants, Comfort Food, Chicken Shop, Amer...
# 7162   [Restaurants, Italian, , , , , , , , , , , , , ]
# 7455  [Restaurants, Mediterranean, Barbeque, Halal, ...
# 7744     [Restaurants, Pizza, , , , , , , , , , , , , ]
# 7920  [Restaurants, Sandwiches, Salad, , , , , , , ,...
# 8186  [Restaurants, Vegan, Middle Eastern, , , , , ,...
# 8205  [Restaurants, Venezuelan, Sandwiches, Food, Co...
# 8356  [Sandwiches, Mediterranean, Restaurants, Middl...
# 8505  [Seafood, Restaurants, Caribbean, , , , , , , ...
# 8705  [Specialty Schools, Caterers, Event Planning &...
# 8744  [Sporting Goods, Shopping, , , , , , , , , , ,...
# 8754  [Sporting Goods, Shopping, Fashion, ShoeStores...
# 8831  [Supernatural Readings, Astrologers, LifeCoach...
# 8889  [Sushi Bars, Restaurants, , , , , , , , , , , ...
# 8940  [Swimwear, Fashion, Lingerie, Shopping, , , , ...
#
# [261 rows x 4 columns]

# %%
# read in all categories 

a = pd.read_csv('final_categories.csv')
final_categories = []
for x in a.Category:
    final_categories.append(x)
final_categories
# Out:
# ['Afghan',
#  'African',
#  'Airportlounges',
#  'American',
#  'Arabian',
#  'Arcades',
#  'Argentine',
#  'Asian Fusion',
#  'Australian',
#  'Austrian',
#  'Bagels',
#  'Bakeries',
#  'Bangladeshi',
#  'Barbeque',
#  'Bars',
#  'Basque',
#  'Bed&Breakfast',
#  'Beer',
#  'Beer Bar',
#  'Beergardens',
#  'Beerhall',
#  'Belgian',
#  'Bistros',
#  'Brasseries',
#  'Brazilian',
#  'Breakfast & Brunch',
#  'Breweries',
#  'Brewing Supplies',
#  'Brewpubs',
#  'British',
#  'Bubble Tea',
#  'Buffets',
#  'Burgers',
#  'Burmese',
#  'Butcher',
#  'Cabaret',
#  'Cafes',
#  'Cafeteria',
#  'Cajun/Creole',
#  'Cambodian',
#  'Canadian',
#  'Canadian ',
#  'Candy Stores',
#  'Candystores',
#  'Cantonese',
#  'Caribbean',
#  'Caterers',
#  'Champagnebars',
#  'Cheese Shops',
#  'Cheeseshops',
#  'Cheesesteaks',
#  'Chicken Shop',
#  'Chicken Wings',
#  'Chinese',
#  'Chocolatiers & Shops',
#  'Churches',
#  'Cideries',
#  'Cocktail Bars',
#  'Coffee & Tea',
#  'Coffee & Tea Supplies',
#  'Coffee Roasteries',
#  'Colleges&Universities',
#  'Colombian',
#  'Comfort Food',
#  'Convenience Stores',
#  'Cooking Schools',
#  'Creperies',
#  'Cuban',
#  'Cupcakes',
#  'Custom Cakes',
#  'Customcakes',
#  'Czech',
#  'Czech/Slovakian',
#  'Delicatessen',
#  'Delis',
#  'Desserts',
#  'Dim Sum',
#  'Dimsum',
#  'Diners',
#  'Dinnertheater',
#  'Discount Store',
#  'Discountstore',
#  'Distilleries',
#  'Dive Bars',
#  'Do-It-Yourself Food',
#  'Do-It-Yourselffood',
#  'Donairs',
#  'Donuts',
#  'Egyptian',
#  'Ethical Grocery',
#  'Ethicalgrocery',
#  'Ethiopian',
#  'Ethnic Food',
#  'Ethnic Grocery',
#  'Ethnicgrocery',
#  'Falafel',
#  'Farmers Market',
#  'Farmersmarket',
#  'Fast Food',
#  'Filipino',
#  'Fish & Chips',
#  'Florists',
#  'Flowers & Gifts',
#  'Fondue',
#  'Food',
#  'Food Court',
#  'Food Stands',
#  'Food Tours',
#  'Food Trucks',
#  'French',
#  'Fruits & Veggies',
#  'Gastropubs',
#  'Gaybars',
#  'Gelato',
#  'German',
#  'Gluten-Free',
#  'Greek',
#  'Grocery',
#  'Hainan',
#  'Hakka',
#  'Halal',
#  'Hawaiian',
#  'Headshops',
#  'Healthretreats',
#  'Herbs & Spices',
#  'Himalayan/Nepalese',
#  'Hobbyshops',
#  'Hookahbars',
#  'Hot Dogs',
#  'Hot Pot',
#  'Hotdogs',
#  'Hotpot',
#  'Hungarian',
#  'Iberian',
#  'Ice Cream & Frozen Yogurt',
#  'Indian',
#  'Indonesian',
#  'Internet Cafes',
#  'Investing',
#  'Irish',
#  'Irish Pub',
#  'Irishpub',
#  'Italian',
#  'Izakaya',
#  'Japanese',
#  'Juice Bars & Smoothies',
#  'Karaoke',
#  'Kebab',
#  'Kombucha',
#  'Korean',
#  'Kosher',
#  'Languageschools',
#  'Laotian',
#  'Latin American',
#  'Lebanese',
#  'Live/Raw Food',
#  'Live/Rawfood',
#  'Local Flavor',
#  'Macarons',
#  'Malaysian',
#  'Marketing',
#  'Meat Shops',
#  'Mediterranean',
#  'Mexican',
#  'Middle Eastern',
#  'Middle Schools & High Schools',
#  'Minho',
#  'Modern European',
#  'Mongolian',
#  'Moroccan',
#  'Nicaraguan',
#  'Nightlife',
#  'Noodles',
#  'Pakistani',
#  'Pan Asian',
#  'Panasian',
#  'Pastashops',
#  'Patisserie/Cake Shop',
#  'Patisserie/Cakeshop',
#  'Pawn Shops',
#  'Pawnshops',
#  'Persian/Iranian',
#  'Personal Chefs',
#  'Personalchefs',
#  'Peruvian',
#  'Pizza',
#  'Plumbing',
#  'Poke',
#  'Polish',
#  'Poolhalls',
#  'Portuguese',
#  'Poutineries',
#  'Pretzels',
#  'Pubs',
#  'Ramen',
#  'Restaurants',
#  'Russian',
#  'Salad',
#  'Salvadoran',
#  'Sandwiches',
#  'Scandinavian',
#  'Scottish',
#  'Seafood',
#  'Seafood Markets',
#  'Seafoodmarkets',
#  'Shanghainese',
#  'Shavedsnow',
#  'Singaporean',
#  'Skincare',
#  'Slovakian',
#  'Smokehouse',
#  'Soul Food',
#  'Soup',
#  'South African',
#  'Southafrican',
#  'Southern',
#  'Spanish',
#  'Specialty Food',
#  'Specialty Schools',
#  'Specialtyschools',
#  'Sporting Goods',
#  'Sports Bars',
#  'Sports Wear',
#  'Sportswear',
#  'Sri Lankan',
#  'Srilankan',
#  'Steakhouses',
#  'Street Vendors',
#  'Sushi Bars',
#  'Sushibars',
#  'Syrian',
#  'Szechuan',
#  'Taiwanese',
#  'Tapas Bars',
#  'Tapas/Small Plates',
#  'Tapasbars',
#  'Tea Rooms',
#  'Tex-Mex',
#  'Thai',
#  'Themedcafes',
#  'Thriftstores',
#  'Ticket Sales',
#  'Tiki Bars',
#  'Tikibars',
#  'Tobaccoshops',
#  'Turkish',
#  'Udon',
#  'Ukrainian',
#  'Vegan',
#  'Vegetarian',
#  'Venezuelan',
#  'Vietnamese',
#  'Waffles',
#  'Whiskey Bars',
#  'Wraps']

# %%
toronto = toronto.sort_values(by=['stars'],ascending=False)
toronto
# Out:
#                  business_id                                      name  \
# 5623  D2SPZOCER3TLIsrYywMpYQ           "Raise the Root Organic Market"
# 3604  tJqPUAk3xU6IkFgagpD92A                    "Di Liso's Fine Meats"
# 5036  rYhgn9JU8E_RxXWzzUiAGA           "Macelleria Atlas Butcher Shop"
# 4110  4wlqqIbuNOEFn8ub4dJxlQ                        "The Healthy Road"
# 3576  NrFsdILQztHSlIUNra82nQ                               "Juice Box"
# 8705  Nvj_rKyKainH4QDPU59AIg                            "Elle Cuisine"
# 2889  dy-qs8C-BuHtFDhvY4GYng                                    "LCBO"
# 3587  InNbPyC-wZli-CcLdaitFQ                           "Booster Juice"
# 2864  rcOzQrCZaX7IbocXmD-M9Q                        "York Station Bar"
# 4104  6kIlmP82sIq2jxhNGUkEtg                   "St Patricks Mini Mart"
# 2852  WM1C5gtPzFFcWF_bV5H3fQ                       "Cock-A-Doodle-Doo"
# 252   iYVHx6Yy1Ut8JjLY40eUyg               "Patricia's Cake Creations"
# 690   YfsaoWDTBKpR09Q90Kw_yA                              "Sugar Loaf"
# 4097  EvsHlX_KPQjfVHRHT6UXZg                      "Lily Fruits Market"
# 2847  Tn1_yYMtMeIprdBD4ouGFA               "Sullivan & Bleeker Baking"
# 3606  7yKB50xvZ4eoG_02lC2CMw                "Grace Meats & Fine Foods"
# 6617  s3Y5_k8vGnWfXjGwke89XA                   "Eupin Chinese Takeout"
# 8268  i98bG3x6orc9TiIw7Xouew                        "Caspi Restaurant"
# 6634  TaA8quY8yKqRfHDUmzTTiA                        "Caribbean Nights"
# 2819  H5oLlt9G6ifU11n86oP5Fg                              "Cobs Bread"
# 299   VKKC3SVIjrA6yf1OFLogvg                             "Cob's Bread"
# 5037  P2ZSZg5ZxF01PhdfMyzdYg                         "Witteveen Meats"
# 669   OD1B3uiFLMCKUsl7wHWxHA                    "New World Wine Tours"
# 5040                  #NAME?                         "Caprae & Suidae"
# 1275  lzrFRbdvpnLJze9VqJigLw     "Caribbean Sunset Restaurant and Bar"
# 1811  YmluvmfqkfE8tZ33fpKGWw                               "Starbucks"
# 3527  0cNPtRA30eEOC8JTVEo6Uw                          "Baked on Brock"
# 8726  awKCpe3lO6zVMDYiRFyiRw                             "Mojo Cycles"
# 8724  uzZ9kUgC9DSPFsmwdsz18g                             "Mojo Cycles"
# 2950  k99J9BJuHeUBNOCxV6D97A                            "Noble Coffee"
# ...                      ...                                       ...
# 6504  mSbRhODRzl51Qu8Hv6zZew                  "Broastyy Fried Chicken"
# 6561  xOUd1W3MmyHXnbr3DxDwqg                             "Ho Lee Chow"
# 6788  Blp_HNEoFEiHcGMr6aSU5w                                     "KFC"
# 3016  UaoAGXDJPcpP7yObGZGD_Q                            "Tim Horton's"
# 2653  9MFcLXNi4pbqHsdrH9giZw                   "LaPaz Batchoy Toronto"
# 3443  ldFrsUNIkDbSPYnspn8Pxg                      "Alfredos Fine Food"
# 2711  WvMkxBdYLTh8ikog84ghCA                             "RealEat Inc"
# 5406  DosL3dkLVtTsIYd0XXX-pg               "Fitzgerald's Public House"
# 2713  V4226pZ4bN0mtEGeT7xkuQ                                 "Mamaluv"
# 8715  SkFr3szJf-3crQhi8_BxNw              "Learn Safe Driving Academy"
# 5688  3uvnTtcsz0OxU4m5hOppCQ                             "Pizza Pizza"
# 8471  zbFtY82_ummK4amkT-M04Q              "Jacky's Seafood Restaurant"
# 7621  bRltkvksGMMisHTgtlv-yg                                  "Voglie"
# 7439  ZrL5p18qbu-Ep9zU4YoEtw                             "Wrap & Roll"
# 510   sRnakAK2_JgjMlOszxqo_g                         "Bloc Twenty Two"
# 8785  VAbgxXTEq6ziOh5TICI1Bw               "Jays Shop Stadium Edition"
# 2449  6sBEq5wssRJ8du-1YZkZRg                          "Cashew & Clive"
# 7904  FOMPEDx1Y4yw8Zyeww9zJQ                                  "Subway"
# 6907  e5dj4h4vTvZYQvKPnBvDjw               "Popeyes Louisiana Kitchen"
# 1451  V8_ecisSAvfcwDRMOzh20g               "Christopher Robin Service"
# 2477  fAuadisRgm3a2vAsVAm0Ng                            "Edward Hotel"
# 331   A2Zg1TiCgcO-ww2gZA_gOQ                      "She Takes The Cake"
# 2090  u7bjH0lJcE7Q4BFlKTPJcg         "Swiss Chalet Rotisserie & Grill"
# 4301  IyrwvRwiwsKCiiKoxbHeFA                             "Noor Makkah"
# 4763  omcQohJjl8jDIhLo0M6_cA                     "Mikado Sushi Robata"
# 8349  aXPw7yszWON9ZvXjNJ9bNw                           "Passion Grill"
# 1258  Ue2H-ajY-uBKwGoBDQutCA                           "Wok & Fortune"
# 2143  7n7luTTakOmJmZCzwOAYvA  "Beer & Liquor Delivery Service Toronto"
# 1419  jDD4R43rpV6xcSlInKgsIQ                 "New Tasty Chicken House"
# 1455  D6aN9U5x6kgHmrZa9ydjhg              "Little Ones Kid's Clothing"
#
#                   neighborhood  \
# 5623               Leslieville
# 3604              St. Lawrence
# 5036                       NaN
# 4110                  Corktown
# 3576  Church-Wellesley Village
# 8705                 Riverdale
# 2889              Little Italy
# 3587               Scarborough
# 2864        Financial District
# 4104             Downtown Core
# 2852             Christie Pits
# 252                  Etobicoke
# 690                Leslieville
# 4097                 Chinatown
# 2847                       NaN
# 3606             Bickford Park
# 6617                       NaN
# 8268                       NaN
# 6634                       NaN
# 2819        Bloor-West Village
# 299               The Danforth
# 5037              St. Lawrence
# 669            Ossington Strip
# 5040                       NaN
# 1275                 Riverdale
# 1811               Upper Beach
# 3527         Bloordale Village
# 8726              Roncesvalles
# 8724                  Parkdale
# 2950              The Junction
# ...                        ...
# 6504        Bloor-West Village
# 6561              The Danforth
# 6788              The Danforth
# 3016                  Corktown
# 2653                       NaN
# 3443                       NaN
# 2711                       NaN
# 5406                 The Beach
# 2713              Harbourfront
# 8715                 East York
# 5688               Scarborough
# 8471                  Milliken
# 7621  Church-Wellesley Village
# 7439             Downtown Core
# 510               Little Italy
# 8785    Entertainment District
# 2449    Entertainment District
# 7904  Church-Wellesley Village
# 6907                       NaN
# 1451        Yonge and Eglinton
# 2477                       NaN
# 331           Brockton Village
# 2090        Financial District
# 4301                 Etobicoke
# 4763                  Milliken
# 8349               New Toronto
# 1258               Scarborough
# 2143              The Danforth
# 1419               Leslieville
# 1455                       NaN
#
#                                                 address     city state  \
# 5623                              "1164 Queen Street E"  Toronto    ON
# 3604                                "91 Front Street E"  Toronto    ON
# 5036                            "800 St Clair Avenue W"  Toronto    ON
# 4110                                "518 King Street E"  Toronto    ON
# 3576                                    "491 Church St"  Toronto    ON
# 8705                                "56 Hampton Avenue"  Toronto    ON
# 2889                               "549 College Street"  Toronto    ON
# 3587                                "300 Borough Drive"  Toronto    ON
# 2864                               "100 Front Street W"  Toronto    ON
# 4104                             "20 St Patrick Street"  Toronto    ON
# 2852                               "830 Bloor Street W"  Toronto    ON
# 252                              "4130 Dundas Street W"  Toronto    ON
# 690                             "1062 Gerrard Street E"  Toronto    ON
# 4097                               "300 Spadina Avenue"  Toronto    ON
# 2847                             "142 Martin Ross Ave."  Toronto    ON
# 3606                               "644 College Street"  Toronto    ON
# 6617                      "4750 Yonge Street, Unit 138"  Toronto    ON
# 8268                  "2727 Steeles Avenue W, Unit 101"  Toronto    ON
# 6634                       "3585 Keele Street, Suite 5"  Toronto    ON
# 2819                                  "2204 Bloor St W"  Toronto    ON
# 299                               "156 Danforth Avenue"  Toronto    ON
# 5037                                    "93 Front St E"  Toronto    ON
# 669                        "100 Lower Ossington Avenue"  Toronto    ON
# 5040                                 "1903 Avenue Road"  Toronto    ON
# 1275                                  "753A Queen St E"  Toronto    ON
# 1811                                "637 Kingston Road"  Toronto    ON
# 3527                                "615C Brock Avenue"  Toronto    ON
# 8726                             "2170 Dundas Street W"  Toronto    ON
# 8724                              "1652 Queen Street W"  Toronto    ON
# 2950                              "1421 Bloor Street W"  Toronto    ON
# ...                                                 ...      ...   ...
# 6504                             "2184A Bloor Street W"  Toronto    ON
# 6561                             "2204 Danforth Avenue"  Toronto    ON
# 6788                             "2500 Danforth Avenue"  Toronto    ON
# 3016                                "Richmond Street E"  Toronto    ON
# 2653                                "360 Wilson Avenue"  Toronto    ON
# 3443                                  "405 Jane Street"  Toronto    ON
# 2711                                                 ""  Toronto    ON
# 5406                              "2298 Queen Street E"  Toronto    ON
# 2713                                 "18 Banigan Drive"  Toronto    ON
# 8715                        "1033 Pape Avenue, Suite 5"  Toronto    ON
# 5688                     "4447 Kingston Road, Unit 7-8"  Toronto    ON
# 8471                              "3380 Midland Avenue"  Toronto    ON
# 7621                                "582 Church Street"  Toronto    ON
# 7439                                 "519 Yonge Street"  Toronto    ON
# 510                                "587 College Street"  Toronto    ON
# 8785                             "Gate 5 Rogers Centre"  Toronto    ON
# 2449  "Metro Toronto Convention Centre, 222 Bremner ...  Toronto    ON
# 7904                                 "607 Yonge Street"  Toronto    ON
# 6907                                "4700 Keele Street"  Toronto    ON
# 1451                            "119 Eglinton Avenue W"  Toronto    ON
# 2477                           "185 Yorkland Boulevard"  Toronto    ON
# 331                              "1600 Dundas Street W"  Toronto    ON
# 2090                              "200 Bay St, Unit F1"  Toronto    ON
# 4301                                 "1158 Albion Road"  Toronto    ON
# 4763                             "1883 McNicoll Avenue"  Toronto    ON
# 8349                      "2836 Lake Shore Boulevard W"  Toronto    ON
# 1258                           "2900 Eglinton Avenue E"  Toronto    ON
# 2143                                                 ""  Toronto    ON
# 1419                                  "1014 Queen St E"  Toronto    ON
# 1455                            "372 Eglinton Avenue W"  Toronto    ON
#
#      postal_code   latitude  longitude  stars  review_count  is_open  \
# 5623     M4M 1L4  43.662724 -79.332594    5.0             5        1
# 3604     M5E 1C3  43.648923 -79.371723    5.0             4        1
# 5036     M6C 1B6  43.680986 -79.429997    5.0             5        1
# 4110     M5A 1M1  43.656381 -79.357038    5.0             5        1
# 3576     M4Y 2C6  43.665187 -79.380587    5.0            12        1
# 8705     M4K 2Y5  43.673511 -79.351334    5.0             3        1
# 2889     M6G 1A9  43.655612 -79.411883    5.0             4        1
# 3587         M1P  43.776875 -79.256655    5.0             3        1
# 2864     M5J 1E3  43.645905 -79.381464    5.0            10        0
# 4104     M5T 2Y4  43.650943 -79.389171    5.0             5        1
# 2852     M6G 1M2  43.662581 -79.423498    5.0            12        1
# 252      M8X 1X3  43.661918 -79.507272    5.0            10        1
# 690      M4M 1Z8  43.669307 -79.335864    5.0             5        1
# 4097     M5T 2E7  43.653342 -79.398332    5.0             4        0
# 2847     M3J 2L9  43.773153 -79.479862    5.0             6        1
# 3606     M6G 1B8  43.655188 -79.415922    5.0             9        1
# 6617     M2N 5M6  43.760286 -79.412207    5.0             4        1
# 8268     M3J 3G9  43.782385 -79.489202    5.0             4        1
# 6634     M3J 3H5  43.750672 -79.486962    5.0             4        0
# 2819         M6P  43.651317 -79.475471    5.0            10        1
# 299      M4K 1N1  43.676686 -79.357480    5.0             4        1
# 5037     M5E 1C3  43.649052 -79.371774    5.0             4        1
# 669      M6J 0A7  43.644875 -79.419129    5.0             3        1
# 5040     M5M 3Z9  43.732967 -79.419268    5.0             3        1
# 1275     M4M 1H3  43.659178 -79.348032    5.0             4        1
# 1811     M4E 1R3  43.678770 -79.298078    5.0             4        1
# 3527     M6H 3P1  43.659613 -79.438638    5.0             8        1
# 8726     M6R 1X3  43.653362 -79.450537    5.0             9        1
# 8724     M6R 1B2  43.639292 -79.443298    5.0             7        1
# 2950     M6P 3L4  43.657146 -79.447877    5.0             6        1
# ...          ...        ...        ...    ...           ...      ...
# 6504     M6S 1N3  43.651649 -79.474643    1.0             3        0
# 6561     M4C 1K3  43.686596 -79.309844    1.0            10        1
# 6788     M4C 1L2  43.688243 -79.302762    1.0             4        1
# 3016     M5A 4S8  43.653376 -79.369116    1.0             3        1
# 2653     M3H 1S9  43.736489 -79.438382    1.0             3        1
# 3443     M6S 3Z6  43.658440 -79.488147    1.0             7        0
# 2711     M2J 4R4  43.773441 -79.331924    1.0             3        1
# 5406     M4E 1G8  43.673515 -79.283998    1.0             3        0
# 2713     M5J 2G2  43.639880 -79.377294    1.0             3        1
# 8715     M4K 3W1  43.689742 -79.348568    1.0             3        1
# 5688     M1E 2N7  43.768508 -79.187950    1.0             3        1
# 8471     M1V 1R4  43.809249 -79.290109    1.0             5        1
# 7621     M4Y 2E5  43.666819 -79.381733    1.0             3        1
# 7439     M4Y 1Y3  43.663647 -79.384006    1.0            11        0
# 510      M6G 1B4  43.654987 -79.413330    1.0             3        1
# 8785     M5V 1J1  43.641390 -79.388172    1.0             3        1
# 2449     M5V 2T6  43.642912 -79.385402    1.0             5        1
# 7904     M4Y 1Z5  43.666817 -79.385210    1.0             4        1
# 6907         M3J  43.774258 -79.493176    1.0             4        1
# 1451     M4R 1A4  43.705833 -79.402653    1.0             3        1
# 2477     M2J 4R2  43.770761 -79.336320    1.0             3        1
# 331      M6K 1T8  43.649862 -79.435090    1.0             3        0
# 2090     M5J 2J1  43.646449 -79.379615    1.0             3        1
# 4301     M9V 1A8  43.737835 -79.568549    1.0             3        1
# 4763     M1V 5M3  43.810043 -79.306207    1.0             3        0
# 8349     M8V 2Y6  43.601685 -79.501768    1.0             3        1
# 1258     M1J 2E4  43.738868 -79.238334    1.0             4        1
# 2143         NaN  43.687603 -79.301051    1.0             3        1
# 1419     M4M 1K1  43.661320 -79.338936    1.0             6        1
# 1455     M5N 1A2  43.704598 -79.409564    1.0             3        1
#
#                                                   final  \
# 5623  ["Organic Stores","Food","Health Markets","Spe...
# 3604  ["Food","Meat Shops","Specialty Food","","",""...
# 5036  ["Meat Shops","Food","Specialty Food","","",""...
# 4110  ["Grocery","OrganicStores","Food","","","","",...
# 3576  ["Food","Juice Bars & Smoothies","","","","","...
# 8705  ["Specialty Schools","Caterers","Event Plannin...
# 2889  ["Food","Beer","Wine & Spirits","","","","",""...
# 3587  ["Food","Juice Bars & Smoothies","","","","","...
# 2864  ["Food","Bars","Nightlife","","","","","","","...
# 4104  ["Grocery","Ice Cream & Frozen Yogurt","Food",...
# 2852  ["Food","Bakeries","Gluten-Free","Restaurants"...
# 252   ["Bakeries","Cafes","Food","Desserts","Restaur...
# 690   ["Breakfast & Brunch","Bakeries","Cafes","Food...
# 4097  ["Grocery","Food","Juice Bars & Smoothies","",...
# 2847  ["Food","Bakeries","Desserts","","","","","","...
# 3606  ["Food","Meat Shops","Specialty Food","","",""...
# 6617  ["Restaurants","Chinese","","","","","","","",...
# 8268  ["Russian","Specialty Food","Ukrainian","Resta...
# 6634  ["Restaurants","Chinese","Caribbean","German",...
# 2819  ["Food","Bakeries","","","","","","","","","",...
# 299   ["Bakeries","Food","","","","","","","","","",...
# 5037  ["Meat Shops","Food","Specialty Food","","",""...
# 669   ["Beer","Wine & Spirits","WineTours","Hotels &...
# 5040  ["Meat Shops","Food","Specialty Food","Butcher...
# 1275  ["Caribbean","Restaurants","","","","","","","...
# 1811  ["Coffee & Tea","Food","","","","","","","",""...
# 3527  ["Food","Ice Cream & Frozen Yogurt","","","","...
# 8726  ["Sporting Goods","Bikes","Shopping","","","",...
# 8724  ["Sporting Goods","Bikes","LocalServices","Sho...
# 2950  ["Food","Cafes","Coffee & Tea","Restaurants","...
# ...                                                 ...
# 6504  ["Restaurants","Chicken Wings","","","","","",...
# 6561  ["Restaurants","Chinese","","","","","","","",...
# 6788  ["Restaurants","Fast Food","","","","","","","...
# 3016  ["Food","Coffee & Tea","","","","","","","",""...
# 2653  ["Fast Food","Soup","Filipino","Restaurants","...
# 3443  ["Food","Grocery","","","","","","","","","","...
# 2711  ["Food Delivery Services","Food","","","","","...
# 5406  ["Nightlife","Bars","Pubs","","","","","","","...
# 2713  ["Food Delivery Services","Food","","","","","...
# 8715  ["Specialty Schools","Education","DrivingSchoo...
# 5688  ["Pizza","Fast Food","Sandwiches","Restaurants...
# 8471  ["Seafood","Chinese","Restaurants","","","",""...
# 7621  ["Restaurants","Nightlife","Bars","","","","",...
# 7439  ["Restaurants","Mediterranean","","","","","",...
# 510   ["Bars","Lounges","Restaurants","Nightlife",""...
# 8785  ["Sports Wear","Shopping","Sporting Goods","Fa...
# 2449  ["Event Planning & Services","Caterers","","",...
# 7904  ["Restaurants","Sandwiches","Fast Food","","",...
# 6907  ["Restaurants","Food","Fast Food","American","...
# 1451  ["Child Care & Day Care","LocalServices","",""...
# 2477  ["Event Planning & Services","Hotels","Hotels ...
# 331   ["Bakeries","Food","","","","","","","","","",...
# 2090  ["Comfort Food","American","","","","","","","...
# 4301  ["Indian","Restaurants","","","","","","","","...
# 4763  ["Japanese","SushiBars","Restaurants","","",""...
# 8349  ["Sandwiches","Halal","Burgers","American","",...
# 1258  ["Caribbean","Chinese","Restaurants","","","",...
# 2143  ["Couriers & Delivery Services","Beer","Wine &...
# 1419  ["Chicken Wings","Restaurants","","","","","",...
# 1455  ["Children's Clothing","ShoeStores","Fashion",...
#
#                                              categories
# 5623  [Organic Stores, Food, Health Markets, Special...
# 3604  [Food, Meat Shops, Specialty Food, , , , , , ,...
# 5036  [Meat Shops, Food, Specialty Food, , , , , , ,...
# 4110  [Grocery, OrganicStores, Food, , , , , , , , ,...
# 3576  [Food, Juice Bars & Smoothies, , , , , , , , ,...
# 8705  [Specialty Schools, Caterers, Event Planning &...
# 2889  [Food, Beer, Wine & Spirits, , , , , , , , , ,...
# 3587  [Food, Juice Bars & Smoothies, , , , , , , , ,...
# 2864    [Food, Bars, Nightlife, , , , , , , , , , , , ]
# 4104  [Grocery, Ice Cream & Frozen Yogurt, Food, , ,...
# 2852  [Food, Bakeries, Gluten-Free, Restaurants, , ,...
# 252   [Bakeries, Cafes, Food, Desserts, Restaurants,...
# 690   [Breakfast & Brunch, Bakeries, Cafes, Food, Co...
# 4097  [Grocery, Food, Juice Bars & Smoothies, , , , ...
# 2847  [Food, Bakeries, Desserts, , , , , , , , , , ,...
# 3606  [Food, Meat Shops, Specialty Food, , , , , , ,...
# 6617   [Restaurants, Chinese, , , , , , , , , , , , , ]
# 8268  [Russian, Specialty Food, Ukrainian, Restauran...
# 6634  [Restaurants, Chinese, Caribbean, German, , , ...
# 2819         [Food, Bakeries, , , , , , , , , , , , , ]
# 299          [Bakeries, Food, , , , , , , , , , , , , ]
# 5037  [Meat Shops, Food, Specialty Food, , , , , , ,...
# 669   [Beer, Wine & Spirits, WineTours, Hotels & Tra...
# 5040  [Meat Shops, Food, Specialty Food, Butcher, , ...
# 1275  [Caribbean, Restaurants, , , , , , , , , , , ,...
# 1811     [Coffee & Tea, Food, , , , , , , , , , , , , ]
# 3527  [Food, Ice Cream & Frozen Yogurt, , , , , , , ...
# 8726  [Sporting Goods, Bikes, Shopping, , , , , , , ...
# 8724  [Sporting Goods, Bikes, LocalServices, Shoppin...
# 2950  [Food, Cafes, Coffee & Tea, Restaurants, Sandw...
# ...                                                 ...
# 6504  [Restaurants, Chicken Wings, , , , , , , , , ,...
# 6561   [Restaurants, Chinese, , , , , , , , , , , , , ]
# 6788  [Restaurants, Fast Food, , , , , , , , , , , ,...
# 3016     [Food, Coffee & Tea, , , , , , , , , , , , , ]
# 2653  [Fast Food, Soup, Filipino, Restaurants, , , ,...
# 3443          [Food, Grocery, , , , , , , , , , , , , ]
# 2711  [Food Delivery Services, Food, , , , , , , , ,...
# 5406    [Nightlife, Bars, Pubs, , , , , , , , , , , , ]
# 2713  [Food Delivery Services, Food, , , , , , , , ,...
# 8715  [Specialty Schools, Education, DrivingSchools,...
# 5688  [Pizza, Fast Food, Sandwiches, Restaurants, , ...
# 8471  [Seafood, Chinese, Restaurants, , , , , , , , ...
# 7621  [Restaurants, Nightlife, Bars, , , , , , , , ,...
# 7439  [Restaurants, Mediterranean, , , , , , , , , ,...
# 510   [Bars, Lounges, Restaurants, Nightlife, , , , ...
# 8785  [Sports Wear, Shopping, Sporting Goods, Fashio...
# 2449  [Event Planning & Services, Caterers, , , , , ...
# 7904  [Restaurants, Sandwiches, Fast Food, , , , , ,...
# 6907  [Restaurants, Food, Fast Food, American, , , ,...
# 1451  [Child Care & Day Care, LocalServices, , , , ,...
# 2477  [Event Planning & Services, Hotels, Hotels & T...
# 331          [Bakeries, Food, , , , , , , , , , , , , ]
# 2090  [Comfort Food, American, , , , , , , , , , , ,...
# 4301    [Indian, Restaurants, , , , , , , , , , , , , ]
# 4763  [Japanese, SushiBars, Restaurants, , , , , , ,...
# 8349  [Sandwiches, Halal, Burgers, American, , , , ,...
# 1258  [Caribbean, Chinese, Restaurants, , , , , , , ...
# 2143  [Couriers & Delivery Services, Beer, Wine & Sp...
# 1419  [Chicken Wings, Restaurants, , , , , , , , , ,...
# 1455  [Children's Clothing, ShoeStores, Fashion, Sho...
#
# [9349 rows x 14 columns]

# %%
name = []
category = []

for i, n in enumerate(toronto.categories):
    for x in n:
        for y in final_categories:
            if x == y:
                name.append(toronto.iloc[i,1])
                category.append(x)
                
a = pd.DataFrame({
    'name': name,
    'category': category
})
# a = a.merge(toronto,left_on='name',right_on='name',how='left')[['name','category','stars']]

# %%
a.to_csv('name_category_stars.csv',index=False, header=False)

# %% [raw]
# def guess(guess_name):
#     guess_name = eval(input('Pick a category: '))
#     for x in final_categories:
#         for y in toronto.categories:
#             for z in y:
#                 if z == guess_name:
#                     # how to print the same
#                     print(toronto['name'])
# guess('American')

# %% [raw]
# df_name = pd.DataFrame(name)
# df_name.head()
# df_name.to_csv('name.csv',index=False, header=False)

# %%
dc = '.'.join(final_categories)
dc
# Out:
# 'Afghan.African.Airportlounges.American.Arabian.Arcades.Argentine.Asian Fusion.Australian.Austrian.Bagels.Bakeries.Bangladeshi.Barbeque.Bars.Basque.Bed&Breakfast.Beer.Beer Bar.Beergardens.Beerhall.Belgian.Bistros.Brasseries.Brazilian.Breakfast & Brunch.Breweries.Brewing Supplies.Brewpubs.British.Bubble Tea.Buffets.Burgers.Burmese.Butcher.Cabaret.Cafes.Cafeteria.Cajun/Creole.Cambodian.Canadian.Canadian .Candy Stores.Candystores.Cantonese.Caribbean.Caterers.Champagnebars.Cheese Shops.Cheeseshops.Cheesesteaks.Chicken Shop.Chicken Wings.Chinese.Chocolatiers & Shops.Churches.Cideries.Cocktail Bars.Coffee & Tea.Coffee & Tea Supplies.Coffee Roasteries.Colleges&Universities.Colombian.Comfort Food.Convenience Stores.Cooking Schools.Creperies.Cuban.Cupcakes.Custom Cakes.Customcakes.Czech.Czech/Slovakian.Delicatessen.Delis.Desserts.Dim Sum.Dimsum.Diners.Dinnertheater.Discount Store.Discountstore.Distilleries.Dive Bars.Do-It-Yourself Food.Do-It-Yourselffood.Donairs.Donuts.Egyptian.Ethical Grocery.Ethicalgrocery.Ethiopian.Ethnic Food.Ethnic Grocery.Ethnicgrocery.Falafel.Farmers Market.Farmersmarket.Fast Food.Filipino.Fish & Chips.Florists.Flowers & Gifts.Fondue.Food.Food Court.Food Stands.Food Tours.Food Trucks.French.Fruits & Veggies.Gastropubs.Gaybars.Gelato.German.Gluten-Free.Greek.Grocery.Hainan.Hakka.Halal.Hawaiian.Headshops.Healthretreats.Herbs & Spices.Himalayan/Nepalese.Hobbyshops.Hookahbars.Hot Dogs.Hot Pot.Hotdogs.Hotpot.Hungarian.Iberian.Ice Cream & Frozen Yogurt.Indian.Indonesian.Internet Cafes.Investing.Irish.Irish Pub.Irishpub.Italian.Izakaya.Japanese.Juice Bars & Smoothies.Karaoke.Kebab.Kombucha.Korean.Kosher.Languageschools.Laotian.Latin American.Lebanese.Live/Raw Food.Live/Rawfood.Local Flavor.Macarons.Malaysian.Marketing.Meat Shops.Mediterranean.Mexican.Middle Eastern.Middle Schools & High Schools.Minho.Modern European.Mongolian.Moroccan.Nicaraguan.Nightlife.Noodles.Pakistani.Pan Asian.Panasian.Pastashops.Patisserie/Cake Shop.Patisserie/Cakeshop.Pawn Shops.Pawnshops.Persian/Iranian.Personal Chefs.Personalchefs.Peruvian.Pizza.Plumbing.Poke.Polish.Poolhalls.Portuguese.Poutineries.Pretzels.Pubs.Ramen.Restaurants.Russian.Salad.Salvadoran.Sandwiches.Scandinavian.Scottish.Seafood.Seafood Markets.Seafoodmarkets.Shanghainese.Shavedsnow.Singaporean.Skincare.Slovakian.Smokehouse.Soul Food.Soup.South African.Southafrican.Southern.Spanish.Specialty Food.Specialty Schools.Specialtyschools.Sporting Goods.Sports Bars.Sports Wear.Sportswear.Sri Lankan.Srilankan.Steakhouses.Street Vendors.Sushi Bars.Sushibars.Syrian.Szechuan.Taiwanese.Tapas Bars.Tapas/Small Plates.Tapasbars.Tea Rooms.Tex-Mex.Thai.Themedcafes.Thriftstores.Ticket Sales.Tiki Bars.Tikibars.Tobaccoshops.Turkish.Udon.Ukrainian.Vegan.Vegetarian.Venezuelan.Vietnamese.Waffles.Whiskey Bars.Wraps'

# %% [raw]
# b = pd.read_csv('final.csv')
# final = []
# for x in b.category:
#     final.append(x)
# dc = '.'.join(final)
# dc

# %% [raw]
# wordcloud = WordCloud(
#
#                           background_color='black',
#                           width=1500,
#                           height=800).generate(dc)
#
#
# plt.figure( figsize=(15,8), facecolor='k')
# plt.imshow(wordcloud)
# plt.axis('off')
# plt.tight_layout(pad=0)
# plt.show()
# # plt.savefig("wordcloud.png")

# %% [raw]
# df_lst = pd.DataFrame(lst)
# # df_lst = df_lst.fillna(4)
# df_lst.to_csv('final.csv',index=False, header=False)

# %% [raw]
# most_stars.head()
# df_most_stars = most_stars.to_csv('most_stars.csv', index=False)
