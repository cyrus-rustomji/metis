# %% [markdown]
# # Imports

# %%
from __future__ import print_function
import pandas as pd
import requests
from requests_oauthlib import OAuth1
import numpy as np
import pickle
from rapidconnect import RapidConnect
import csv
# rapid = RapidConnect('recipe_recs_5b1f0334e4b09cbc0579fe60', '/connect/auth/recipe_recs_5b1f0334e4b09cbc0579fe60')

# %% [markdown]
# # Data Pull

# %% [raw]
# # You can now instantiate a new RapidAPI client with your ProjectName and ProjectKey:
# rapid = RapidConnect('ProjectName', 'ProjectKey')
#
# # Now, to call an API, all you have to do is write the following code:
# result = rapid.call('APIName', 'FunctionName', {
#     'ParameterKey1': 'ParameterValue1',
#     'ParameterKey2': 'ParameterValue2',
# })

# %%
# burgers

burgers = requests.get("https://spoonacular-recipe-food-nutrition-v1.p.mashape.com/recipes/search?number=100&offset=0&query=burger",
  headers={
    "X-Mashape-Key": "1Ms8AuG6SimshCdj9BnBe5CAo2Xjp1vuOc6jsnuNkaOt7P5qXl",
    "X-Mashape-Host": "spoonacular-recipe-food-nutrition-v1.p.mashape.com"
  }
)

bun = burgers.json()
bun
# Out:
# {'results': [{'id': 690978,
#    'title': 'Healthy Salmon Quinoa Burgers ',
#    'readyInMinutes': 45,
#    'servings': 5,
#    'image': 'healthy-salmon-quinoa-burgers-skinnytaste-690978.jpg',
#    'imageUrls': ['healthy-salmon-quinoa-burgers-skinnytaste-690978.jpg']},
#   {'id': 720070,
#    'title': 'Chicken Parmigiana Burgers Skinnytaste',
#    'readyInMinutes': 45,
#    'servings': 10,
#    'image': 'chicken-parmigiana-burgers-skinnytaste-720070.jpg',
#    'imageUrls': ['chicken-parmigiana-burgers-skinnytaste-720070.jpg']},
#   {'id': 428467,
#    'title': 'Pepperoni Pizza Burgers',
#    'readyInMinutes': 15,
#    'servings': 4,
#    'image': 'pepperoni-pizza-burgers-428467.jpg',
#    'imageUrls': ['pepperoni-pizza-burgers-428467.jpg',
#     'Pepperoni-Pizza-Burgers-428467.jpg']},
#   {'id': 574946,
#    'title': 'Paleo Burgers with Caramelized Balsamic Onions & Avocado',
#    'readyInMinutes': 30,
#    'servings': 6,
# ...

# %%
d_bun = bun['results']
a = pd.DataFrame(d_bun)
a.head()
# Out:
#        id                                              image  \
# 0  690978  healthy-salmon-quinoa-burgers-skinnytaste-6909...
# 1  720070  chicken-parmigiana-burgers-skinnytaste-720070.jpg
# 2  428467                 pepperoni-pizza-burgers-428467.jpg
# 3  574946  paleo-burgers-with-caramelized-balsamic-onions...
# 4  473511                            Taco-Burgers-473511.jpg
#
#                                            imageUrls  readyInMinutes  \
# 0  [healthy-salmon-quinoa-burgers-skinnytaste-690...              45
# 1  [chicken-parmigiana-burgers-skinnytaste-720070...              45
# 2  [pepperoni-pizza-burgers-428467.jpg, Pepperoni...              15
# 3  [paleo-burgers-with-caramelized-balsamic-onion...              30
# 4                          [Taco-Burgers-473511.jpg]              25
#
#    servings                                              title
# 0         5                     Healthy Salmon Quinoa Burgers
# ...

# %%
# curry

curry = requests.get("https://spoonacular-recipe-food-nutrition-v1.p.mashape.com/recipes/search?number=100&offset=0&query=curry",
  headers={
    "X-Mashape-Key": "1Ms8AuG6SimshCdj9BnBe5CAo2Xjp1vuOc6jsnuNkaOt7P5qXl",
    "X-Mashape-Host": "spoonacular-recipe-food-nutrition-v1.p.mashape.com"
  }
)

rice = curry.json()
rice
# Out:
# {'results': [{'id': 951559,
#    'title': 'Curried Chickpeas with Spinach',
#    'readyInMinutes': 25,
#    'servings': 4,
#    'image': 'curried-chickpeas-with-spinach-951559.jpg',
#    'imageUrls': ['curried-chickpeas-with-spinach-951559.jpg']},
#   {'id': 985334,
#    'title': 'Coconut Shrimp Curry',
#    'readyInMinutes': 25,
#    'servings': 4,
#    'image': 'coconut-shrimp-curry-985334.jpg',
#    'imageUrls': ['coconut-shrimp-curry-985334.jpg']},
#   {'id': 512694,
#    'title': 'Coconut Shrimp and Chickpea Curry',
#    'readyInMinutes': 40,
#    'servings': 6,
#    'image': 'Coconut-Shrimp-and-Chickpea-Curry-+-Prevention-RD-Cookbook-Giveaway-512694.jpg',
#    'imageUrls': ['Coconut-Shrimp-and-Chickpea-Curry-+-Prevention-RD-Cookbook-Giveaway-512694.jpg']},
#   {'id': 560126,
#    'title': 'Curry Chicken in Basil Coconut Sauce',
#    'readyInMinutes': 30,
#    'servings': 4,
#    'image': 'Curry-Chicken-in-Basil-Coconut-Sauce-560126.jpg',
# ...

# %%
d_rice = rice['results']
b = pd.DataFrame(d_rice)
b.head()
# Out:
#        id                                              image  \
# 0  951559          curried-chickpeas-with-spinach-951559.jpg
# 1  985334                    coconut-shrimp-curry-985334.jpg
# 2  512694  Coconut-Shrimp-and-Chickpea-Curry-+-Prevention...
# 3  560126    Curry-Chicken-in-Basil-Coconut-Sauce-560126.jpg
# 4  509498  Leftovers--Crockpot-Brazilian-Curry-Chicken-50...
#
#                                            imageUrls  readyInMinutes  \
# 0        [curried-chickpeas-with-spinach-951559.jpg]              25
# 1                  [coconut-shrimp-curry-985334.jpg]              25
# 2  [Coconut-Shrimp-and-Chickpea-Curry-+-Preventio...              40
# 3  [Curry-Chicken-in-Basil-Coconut-Sauce-560126.jpg]              30
# 4  [Leftovers--Crockpot-Brazilian-Curry-Chicken-5...              10
#
#    servings                                        title
# 0         4               Curried Chickpeas with Spinach
# 1         4                         Coconut Shrimp Curry
# ...

# %%
# tacos

taco = requests.get("https://spoonacular-recipe-food-nutrition-v1.p.mashape.com/recipes/search?number=1000&offset=0&query=taco",
  headers={
    "X-Mashape-Key": "1lgfQw0SXHmshZG3AhwpBY3kw2U6p1ACeknjsnqs9aKB54jT36",
    "X-Mashape-Host": "spoonacular-recipe-food-nutrition-v1.p.mashape.com"
  }
)

meat = taco.json()
meat
# Out:
# {'results': [{'id': 668334,
#    'title': 'Crock Pot Beef Carnitas Tacos',
#    'readyInMinutes': 480,
#    'servings': 6,
#    'image': 'Crock-Pot-Beef-Carnitas-Tacos-668334.jpg',
#    'imageUrls': ['Crock-Pot-Beef-Carnitas-Tacos-668334.jpg']},
#   {'id': 547855,
#    'title': 'Roasted Cauliflower and Chickpea Tacos',
#    'readyInMinutes': 45,
#    'servings': 4,
#    'image': 'Roasted-Cauliflower-and-Chickpea-Tacos-547855.jpg',
#    'imageUrls': ['Roasted-Cauliflower-and-Chickpea-Tacos-547855.jpg']},
#   {'id': 549054,
#    'title': 'Spicy Fish Tacos with Cabbage Slaw + Lime Crema',
#    'readyInMinutes': 25,
#    'servings': 6,
#    'image': 'Spicy-Fish-Tacos-with-Cabbage-Slaw-+-Lime-Crema-549054.jpg',
#    'imageUrls': ['Spicy-Fish-Tacos-with-Cabbage-Slaw-+-Lime-Crema-549054.jpg']},
#   {'id': 577601,
#    'title': 'Chipotle Sweet Potato, Black Bean, and Guac Tacos',
#    'readyInMinutes': 10,
#    'servings': 2,
# ...

# %%
d_taco = meat['results']
c = pd.DataFrame(d_taco)
c.head()
# Out:
#        id                                              image  \
# 0  668334           Crock-Pot-Beef-Carnitas-Tacos-668334.jpg
# 1  547855  Roasted-Cauliflower-and-Chickpea-Tacos-547855.jpg
# 2  549054  Spicy-Fish-Tacos-with-Cabbage-Slaw-+-Lime-Crem...
# 3  577601  Chipotle-Sweet-Potato--Black-Bean--and-Guac-Ta...
# 4  539351  Spicy-Fish-Tacos-with-Avocado-Yogurt-Sauce-539...
#
#                                            imageUrls  readyInMinutes  \
# 0         [Crock-Pot-Beef-Carnitas-Tacos-668334.jpg]             480
# 1  [Roasted-Cauliflower-and-Chickpea-Tacos-547855...              45
# 2  [Spicy-Fish-Tacos-with-Cabbage-Slaw-+-Lime-Cre...              25
# 3  [Chipotle-Sweet-Potato--Black-Bean--and-Guac-T...              10
# 4  [Spicy-Fish-Tacos-with-Avocado-Yogurt-Sauce-53...              40
#
#    servings                                              title
# 0         6                      Crock Pot Beef Carnitas Tacos
# ...

# %%
# pizza

pizza = requests.get("https://spoonacular-recipe-food-nutrition-v1.p.mashape.com/recipes/search?number=1000&offset=0&query=pizza",
  headers={
    "X-Mashape-Key": "1lgfQw0SXHmshZG3AhwpBY3kw2U6p1ACeknjsnqs9aKB54jT36",
    "X-Mashape-Host": "spoonacular-recipe-food-nutrition-v1.p.mashape.com"
  }
)

toppings = pizza.json()
toppings
# Out:
# {'results': [{'id': 630746,
#    'title': 'The Lucky Penny Blog: The BEST Cauliflower Crust Pizza',
#    'readyInMinutes': 45,
#    'servings': 2,
#    'image': 'The-Lucky-Penny-Blog--The-BEST-Cauliflower-Crust-Pizza-630746.jpg',
#    'imageUrls': ['The-Lucky-Penny-Blog--The-BEST-Cauliflower-Crust-Pizza-630746.jpg']},
#   {'id': 569888,
#    'title': 'Pizza Logs',
#    'readyInMinutes': 45,
#    'servings': 8,
#    'image': 'Pizza-Logs-569888.jpg',
#    'imageUrls': ['Pizza-Logs-569888.jpg']},
#   {'id': 516818,
#    'title': 'Cauliflower Crust Hawaiian Pizza',
#    'readyInMinutes': 43,
#    'servings': 2,
#    'image': 'Cauliflower-Crust-Hawaiian-Pizza-516818.jpg',
#    'imageUrls': ['Cauliflower-Crust-Hawaiian-Pizza-516818.jpg']},
#   {'id': 490490,
#    'title': 'Pizza Pinwheels',
#    'readyInMinutes': 45,
#    'servings': 24,
#    'image': 'Pizza-Pinwheels-490490.jpg',
#    'imageUrls': ['Pizza-Pinwheels-490490.jpg']},
#   {'id': 495115,
# ...

# %%
d_toppings = toppings['results']
d = pd.DataFrame(d_toppings)
d.head()
# Out:
#        id                                              image  \
# 0  630746  The-Lucky-Penny-Blog--The-BEST-Cauliflower-Cru...
# 1  569888                              Pizza-Logs-569888.jpg
# 2  516818        Cauliflower-Crust-Hawaiian-Pizza-516818.jpg
# 3  490490                         Pizza-Pinwheels-490490.jpg
# 4  495115              Grilled-Caprese-Naan-Pizza-495115.jpg
#
#                                            imageUrls  readyInMinutes  \
# 0  [The-Lucky-Penny-Blog--The-BEST-Cauliflower-Cr...              45
# 1                            [Pizza-Logs-569888.jpg]              45
# 2      [Cauliflower-Crust-Hawaiian-Pizza-516818.jpg]              43
# 3                       [Pizza-Pinwheels-490490.jpg]              45
# 4            [Grilled-Caprese-Naan-Pizza-495115.jpg]              15
#
#    servings                                              title
# 0         2  The Lucky Penny Blog: The BEST Cauliflower Cru...
# ...

# %%
# pasta

pasta = requests.get("https://spoonacular-recipe-food-nutrition-v1.p.mashape.com/recipes/search?number=1000&offset=0&query=pasta",
  headers={
    "X-Mashape-Key": "1lgfQw0SXHmshZG3AhwpBY3kw2U6p1ACeknjsnqs9aKB54jT36",
    "X-Mashape-Host": "spoonacular-recipe-food-nutrition-v1.p.mashape.com"
  }
)

red_sauce = pasta.json()
red_sauce
# Out:
# {'results': [{'id': 548180,
#    'title': 'Italian Sausage Tortellini Soup',
#    'readyInMinutes': 40,
#    'servings': 6,
#    'image': 'Italian-Sausage-Tortellini-Soup-548180.jpg',
#    'imageUrls': ['Italian-Sausage-Tortellini-Soup-548180.jpg']},
#   {'id': 507501,
#    'title': 'Creamy Mushroom-Fontina Pasta',
#    'readyInMinutes': 45,
#    'servings': 4,
#    'image': 'Creamy-Mushroom-Fontina-Pasta-507501.jpg',
#    'imageUrls': ['Creamy-Mushroom-Fontina-Pasta-507501.jpg']},
#   {'id': 548458,
#    'title': 'Creamy Tomato Tortellini Soup',
#    'readyInMinutes': 35,
#    'servings': 6,
#    'image': 'Creamy-Tomato-Tortellini-Soup-548458.jpg',
#    'imageUrls': ['Creamy-Tomato-Tortellini-Soup-548458.jpg']},
#   {'id': 628008,
#    'title': 'Bucatini with Butter-Roasted Tomato Sauce',
#    'readyInMinutes': 45,
#    'servings': 4,
#    'image': 'Bucatini-with-Butter-Roasted-Tomato-Sauce-628008.jpg',
#    'imageUrls': ['Bucatini-with-Butter-Roasted-Tomato-Sauce-628008.jpg']},
# ...

# %%
d_pasta = red_sauce['results']
e = pd.DataFrame(d_pasta)
e.head()
# Out:
#        id                                              image  \
# 0  548180         Italian-Sausage-Tortellini-Soup-548180.jpg
# 1  507501           Creamy-Mushroom-Fontina-Pasta-507501.jpg
# 2  548458           Creamy-Tomato-Tortellini-Soup-548458.jpg
# 3  628008  Bucatini-with-Butter-Roasted-Tomato-Sauce-6280...
# 4  757883  spaghetti-with-lemon-and-toasted-walnuts-75788...
#
#                                            imageUrls  readyInMinutes  \
# 0       [Italian-Sausage-Tortellini-Soup-548180.jpg]              40
# 1         [Creamy-Mushroom-Fontina-Pasta-507501.jpg]              45
# 2         [Creamy-Tomato-Tortellini-Soup-548458.jpg]              35
# 3  [Bucatini-with-Butter-Roasted-Tomato-Sauce-628...              45
# 4  [spaghetti-with-lemon-and-toasted-walnuts-7578...              45
#
#    servings                                      title
# 0         6            Italian Sausage Tortellini Soup
# 1         4              Creamy Mushroom-Fontina Pasta
# ...

# %%
soup = requests.get("https://spoonacular-recipe-food-nutrition-v1.p.mashape.com/recipes/search?number=1000&offset=0&query=soup",
  headers={
    "X-Mashape-Key": "1lgfQw0SXHmshZG3AhwpBY3kw2U6p1ACeknjsnqs9aKB54jT36",
    "X-Mashape-Host": "spoonacular-recipe-food-nutrition-v1.p.mashape.com"
  }
)

water = soup.json()
water
# Out:
# {'results': [{'id': 474468,
#    'title': 'Hearty Chicken Chorizo, Kale, Bean and Farro Soup',
#    'readyInMinutes': 50,
#    'servings': 6,
#    'image': 'Hearty-Chicken-Chorizo--Kale--Bean-and-Farro-Soup-474468.jpg',
#    'imageUrls': ['Hearty-Chicken-Chorizo--Kale--Bean-and-Farro-Soup-474468.jpg']},
#   {'id': 482574,
#    'title': 'Slow Cooker Vegetarian Chili with Butternut Squash',
#    'readyInMinutes': 250,
#    'servings': 4,
#    'image': 'Slow-Cooker-Vegetarian-Chili-with-Butternut-Squash-482574.jpg',
#    'imageUrls': ['Slow-Cooker-Vegetarian-Chili-with-Butternut-Squash-482574.jpg']},
#   {'id': 615454,
#    'title': '10-Spice Vegetable Soup (Freezer Friendly, Vegan, Gluten-Free)',
#    'readyInMinutes': 60,
#    'servings': 6,
#    'image': '10-spice-vegetable-soup-freezer-friendly-vegan-gluten-free-615454.jpg',
#    'imageUrls': ['10-spice-vegetable-soup-freezer-friendly-vegan-gluten-free-615454.jpg']},
#   {'id': 716381,
#    'title': 'Nigerian Snail Stew',
# ...

# %%
d_water = water['results']
f = pd.DataFrame(d_water)
f.head()
# Out:
#        id                                              image  \
# 0  474468  Hearty-Chicken-Chorizo--Kale--Bean-and-Farro-S...
# 1  482574  Slow-Cooker-Vegetarian-Chili-with-Butternut-Sq...
# 2  615454  10-spice-vegetable-soup-freezer-friendly-vegan...
# 3  716381                     nigerian-snail-stew-716381.jpg
# 4  737832                            chili-beans-737832.jpeg
#
#                                            imageUrls  readyInMinutes  \
# 0  [Hearty-Chicken-Chorizo--Kale--Bean-and-Farro-...              50
# 1  [Slow-Cooker-Vegetarian-Chili-with-Butternut-S...             250
# 2  [10-spice-vegetable-soup-freezer-friendly-vega...              60
# 3                   [nigerian-snail-stew-716381.jpg]              45
# 4                          [chili-beans-737832.jpeg]             745
#
#    servings                                              title
# 0         6  Hearty Chicken Chorizo, Kale, Bean and Farro Soup
# ...

# %%
bbq = requests.get("https://spoonacular-recipe-food-nutrition-v1.p.mashape.com/recipes/search?number=100&offset=0&query=bbq",
  headers={
    "X-Mashape-Key": "1lgfQw0SXHmshZG3AhwpBY3kw2U6p1ACeknjsnqs9aKB54jT36",
    "X-Mashape-Host": "spoonacular-recipe-food-nutrition-v1.p.mashape.com"
  }
)

ribs = bbq.json()
ribs
# Out:
# {'results': [{'id': 714190,
#    'title': 'Barbecue Pulled Pork',
#    'readyInMinutes': 240,
#    'servings': 6,
#    'image': 'barbecue-pulled-pork-714190.jpeg',
#    'imageUrls': ['barbecue-pulled-pork-714190.jpeg']},
#   {'id': 578582,
#    'title': 'Goat Cheese Stuffed Peppers: Spectacular Summer Appetizer For Your Next Barbecue',
#    'readyInMinutes': 30,
#    'servings': 25,
#    'image': 'Goat-Cheese-Stuffed-Peppers--Spectacular-Summer-Appetizer-For-Your-Next-Barbecue-578582.jpg',
#    'imageUrls': ['Goat-Cheese-Stuffed-Peppers--Spectacular-Summer-Appetizer-For-Your-Next-Barbecue-578582.jpg']},
#   {'id': 510978,
#    'title': 'Barbecue Chicken Salad',
#    'readyInMinutes': 15,
#    'servings': 2,
#    'image': 'Barbecue-Chicken-Salad-510978.jpg',
#    'imageUrls': ['Barbecue-Chicken-Salad-510978.jpg']},
#   {'id': 203136,
#    'title': 'Barbecue: Burnt Ends',
#    'readyInMinutes': 1200,
#    'servings': 8,
#    'image': 'Barbecue--Burnt-Ends-203136.jpg',
# ...

# %%
d_ribs = ribs['results']
g = pd.DataFrame(d_ribs)
g.head()
# Out:
#        id                                              image  \
# 0  714190                   barbecue-pulled-pork-714190.jpeg
# 1  578582  Goat-Cheese-Stuffed-Peppers--Spectacular-Summe...
# 2  510978                  Barbecue-Chicken-Salad-510978.jpg
# 3  203136                    Barbecue--Burnt-Ends-203136.jpg
# 4  529873  Sweet-and-Spicy-Barbecue-Pork-with-Asian-Slaw-...
#
#                                            imageUrls  readyInMinutes  \
# 0                 [barbecue-pulled-pork-714190.jpeg]             240
# 1  [Goat-Cheese-Stuffed-Peppers--Spectacular-Summ...              30
# 2                [Barbecue-Chicken-Salad-510978.jpg]              15
# 3                  [Barbecue--Burnt-Ends-203136.jpg]            1200
# 4  [Sweet-and-Spicy-Barbecue-Pork-with-Asian-Slaw...              45
#
#    servings                                              title
# 0         6                               Barbecue Pulled Pork
# ...

# %%
sandwich = requests.get("https://spoonacular-recipe-food-nutrition-v1.p.mashape.com/recipes/search?number=100&offset=0&query=sandwich",
  headers={
    "X-Mashape-Key": "1lgfQw0SXHmshZG3AhwpBY3kw2U6p1ACeknjsnqs9aKB54jT36",
    "X-Mashape-Host": "spoonacular-recipe-food-nutrition-v1.p.mashape.com"
  }
)

food = sandwich.json()
food
# Out:
# {'results': [{'id': 765700,
#    'title': 'Spinach and Ricotta Grilled Cheese',
#    'readyInMinutes': 45,
#    'servings': 2,
#    'image': 'spinach-and-ricotta-grilled-cheese-765700.jpg',
#    'imageUrls': ['spinach-and-ricotta-grilled-cheese-765700.jpg']},
#   {'id': 536064,
#    'title': 'Egg Salad BLTA Sandwich',
#    'readyInMinutes': 25,
#    'servings': 2,
#    'image': 'Egg-Salad-BLTA-Sandwich-536064.jpg',
#    'imageUrls': ['Egg-Salad-BLTA-Sandwich-536064.jpg']},
#   {'id': 608861,
#    'title': 'Pesto, Tomato, and Mozzarella Sandwich',
#    'readyInMinutes': 15,
#    'servings': 4,
#    'image': 'Pesto--Tomato--and-Mozzarella-Sandwich-608861.jpg',
#    'imageUrls': ['Pesto--Tomato--and-Mozzarella-Sandwich-608861.jpg']},
#   {'id': 515949,
#    'title': 'Irish Soda Bread Grilled Cheese with Pesto',
#    'readyInMinutes': 60,
#    'servings': 4,
#    'image': 'Irish-Soda-Bread-Grilled-Cheese-with-Pesto-515949.jpg',
# ...

# %%
d_food = food['results']
h = pd.DataFrame(d_food)
h.head()
# Out:
#        id                                              image  \
# 0  765700      spinach-and-ricotta-grilled-cheese-765700.jpg
# 1  536064                 Egg-Salad-BLTA-Sandwich-536064.jpg
# 2  608861  Pesto--Tomato--and-Mozzarella-Sandwich-608861.jpg
# 3  515949  Irish-Soda-Bread-Grilled-Cheese-with-Pesto-515...
# 4  937890          philly-cheesesteak-sloppy-joes-937890.jpg
#
#                                            imageUrls  readyInMinutes  \
# 0    [spinach-and-ricotta-grilled-cheese-765700.jpg]              45
# 1               [Egg-Salad-BLTA-Sandwich-536064.jpg]              25
# 2  [Pesto--Tomato--and-Mozzarella-Sandwich-608861...              15
# 3  [Irish-Soda-Bread-Grilled-Cheese-with-Pesto-51...              60
# 4        [philly-cheesesteak-sloppy-joes-937890.jpg]              30
#
#    servings                                       title
# 0         2          Spinach and Ricotta Grilled Cheese
# 1         2                     Egg Salad BLTA Sandwich
# ...

# %%
# keep id, title, readyinminutes, and servings

frames = [a,b,c,d,e,f,g,h]
result = pd.concat(frames)
result = result.drop(columns=['image','imageUrls'])
result.head()
# Out:
#        id  readyInMinutes  servings  \
# 0  690978              45         5
# 1  720070              45        10
# 2  428467              15         4
# 3  574946              30         6
# 4  473511              25         4
#
#                                                title
# 0                     Healthy Salmon Quinoa Burgers
# 1             Chicken Parmigiana Burgers Skinnytaste
# 2                            Pepperoni Pizza Burgers
# 3  Paleo Burgers with Caramelized Balsamic Onions...
# 4                                       Taco Burgers

# %%
new = []
for x in result['id']:
    new.append(x)
new
# Out:
# [690978,
#  720070,
#  428467,
#  574946,
#  473511,
#  728903,
#  495417,
#  244482,
#  599841,
#  770555,
#  524571,
#  487210,
#  696544,
#  549102,
#  244749,
#  572532,
#  515952,
#  757215,
#  247548,
#  245166,
#  244436,
#  505226,
#  551623,
#  518227,
#  505924,
#  696135,
#  617940,
#  515112,
#  594403,
#  473265,
#  772924,
#  517893,
#  696063,
#  509586,
#  746272,
#  576954,
#  471356,
#  695624,
#  479748,
#  510907,
#  603675,
#  598542,
#  575558,
#  737383,
#  668706,
#  744628,
#  377241,
#  492404,
#  514888,
#  746358,
#  483868,
#  448496,
#  485921,
#  511110,
#  480050,
#  511904,
#  551404,
#  611457,
#  471589,
#  596550,
#  203990,
#  491511,
#  195863,
#  210821,
#  554075,
#  550888,
#  380690,
#  556173,
#  472292,
#  460160,
#  606709,
#  499232,
#  248393,
#  585070,
#  204752,
#  762361,
#  560392,
#  532797,
#  519363,
#  225225,
#  773346,
#  747176,
#  332587,
#  199980,
#  551508,
#  696496,
#  226495,
#  464732,
#  199964,
#  501162,
# ...

# %% [raw]
# df = pd.DataFrame(new)
# df.to_csv('recipe_id.csv',index=False, header=False)

# %%
response = requests.get("https://spoonacular-recipe-food-nutrition-v1.p.mashape.com/recipes/informationBulk?ids=690978%2C720070%2C428467%2C574946%2C473511%2C728903%2C495417%2C244482%2C599841%2C770555%2C524571%2C487210%2C696544%2C549102%2C244749%2C572532",
  headers={
    "X-Mashape-Key": "1lgfQw0SXHmshZG3AhwpBY3kw2U6p1ACeknjsnqs9aKB54jT36",
    "X-Mashape-Host": "spoonacular-recipe-food-nutrition-v1.p.mashape.com"
  }
)
response
# Out:
# <Response [200]>

# %%
recipe = response.json()
recipe
# Out:
# [{'vegetarian': False,
#   'vegan': False,
#   'glutenFree': True,
#   'dairyFree': True,
#   'veryHealthy': False,
#   'cheap': False,
#   'veryPopular': True,
#   'sustainable': False,
#   'weightWatcherSmartPoints': 6,
#   'gaps': 'no',
#   'lowFodmap': False,
#   'ketogenic': False,
#   'whole30': False,
#   'sourceUrl': 'http://www.skinnytaste.com/2015/03/healthy-salmon-quinoa-burgers.html',
#   'spoonacularSourceUrl': 'https://spoonacular.com/healthy-salmon-quinoa-burgers--690978',
#   'aggregateLikes': 53045,
#   'spoonacularScore': 99.0,
#   'healthScore': 45.0,
#   'creditText': 'Skinny Taste',
#   'sourceName': 'Skinny Taste',
#   'pricePerServing': 272.03,
#   'extendedIngredients': [{'id': 11959,
#     'aisle': 'Produce',
#     'image': 'arugula-or-rocket-salad.jpg',
#     'consitency': 'solid',
#     'name': 'baby arugula',
#     'original': '10 loose cups baby arugula',
#     'originalString': '10 loose cups baby arugula',
#     'originalName': None,
# ...

# %% [markdown]
# # Put all recipes in one dictionary

# %%
spoon = requests.get("https://spoonacular-recipe-food-nutrition-v1.p.mashape.com/recipes/informationBulk?ids=690978%2C720070%2C428467%2C574946%2C473511%2C728903%2C495417%2C244482%2C599841",
  headers={
    "X-Mashape-Key": "1lgfQw0SXHmshZG3AhwpBY3kw2U6p1ACeknjsnqs9aKB54jT36",
    "X-Mashape-Host": "spoonacular-recipe-food-nutrition-v1.p.mashape.com"
  }
)
final = spoon.json()
final
# Out:
# [{'vegetarian': False,
#   'vegan': False,
#   'glutenFree': True,
#   'dairyFree': True,
#   'veryHealthy': False,
#   'cheap': False,
#   'veryPopular': True,
#   'sustainable': False,
#   'weightWatcherSmartPoints': 6,
#   'gaps': 'no',
#   'lowFodmap': False,
#   'ketogenic': False,
#   'whole30': False,
#   'sourceUrl': 'http://www.skinnytaste.com/2015/03/healthy-salmon-quinoa-burgers.html',
#   'spoonacularSourceUrl': 'https://spoonacular.com/healthy-salmon-quinoa-burgers--690978',
#   'aggregateLikes': 53045,
#   'spoonacularScore': 99.0,
#   'healthScore': 45.0,
#   'creditText': 'Skinny Taste',
#   'sourceName': 'Skinny Taste',
#   'pricePerServing': 272.03,
#   'extendedIngredients': [{'id': 11959,
#     'aisle': 'Produce',
#     'image': 'arugula-or-rocket-salad.jpg',
#     'consitency': 'solid',
#     'name': 'baby arugula',
#     'original': '10 loose cups baby arugula',
#     'originalString': '10 loose cups baby arugula',
#     'originalName': None,
# ...

# %%
# find names of recipes
i = 0
z = 0
q = 0
d = 0
r = 0
recipes = []
for x in final:
    if i == 9 or z == 9 or q == 9 or r == 9:
        break
    header = []
    for x in final[i]['title']:
        header = (final[i]['title'])

    # ingredients dictionary
    lst = []
    lst2 = []
    ingredients = {}
    for a in final[z]['extendedIngredients']:
        for key,value in a.items():
            lst.append(a['original'])
    for item in lst:
        if item not in lst2:
            lst2.append(item)

    ingredients['Ingredients'] = lst2

    # instructions dictionary
    duplicate_instrc = []
    instrc = []
    dictionary = {}
    instructions = {}
    if len(final[q]['analyzedInstructions']) == 0:
        instrc = []
    else:
        for r in final[q]['analyzedInstructions'][0]['steps']:
            for key,value in r.items():
                duplicate_instrc.append(r['step'])
        for items in duplicate_instrc:
            if items not in instrc:
                instrc.append(items)

    lst3 = []
    lst4 = []
    lst5 = []
    if len(final[i]['analyzedInstructions']) == 0:
        lst5 = []
    else:
        for y in final[i]['analyzedInstructions'][0]['steps']:
            for key,value in y.items():
                lst3.append(y['number'])
        for elements in lst3:
            if elements not in lst5:
                lst5.append(elements)
        for item in lst:
            if item not in lst4:
                lst4.append(item)

    dictionary = dict(zip(lst5, instrc))
    dictionary
    instructions['Instructions'] = dictionary



    # dish types dictionary -- complete
    dish_types = {}
    ready = {}
    diets = {}
    wine = {}
    cuisines = {}
    full_dictionary = {}
    vegetarian = {}
    vegan = {}
    gluten_free = {}
    dairy_free = {}
    dish_types['Dish Types'] = final[i]['dishTypes']

    ready['Time to Cook'] = final[i]['readyInMinutes']

    # diets dictionary
    diets['Diets'] = final[i]['diets']

    # wine pairings dictionary
    wine['Wine Pairings'] = final[i]['winePairing']['pairedWines']

    # cuisines dictionary
    cuisines['Cuisines'] = final[i]['cuisines']
    vegetarian['Vegetarian'] = final[i]['vegetarian']
    vegan['Vegan'] = final[i]['vegan']
    gluten_free['Gluten-Free'] = final[i]['glutenFree']
    dairy_free['Dairy-Free'] = final[i]['dairyFree']

    # full dictionary
    title = final[i]['title']
        
    full_dictionary[title] = [instructions,ingredients,ready,dish_types,diets,cuisines,vegetarian,vegan,gluten_free,dairy_free,wine]

    # recipes dictionary
    recipes.append(full_dictionary)
    i+=1
    z+=1
    q+=1
    d+=1

# full_dictionary
recipes
# ready
# dish_types
# diets
# wine
# cuisines
# full_dictionary
# dish_types
# instructions
# instrc
# ingredients
# header
# Out:
# [{'Healthy Salmon Quinoa Burgers ': [{'Instructions': {1: 'In a small bowl, whisk the olive oil, vinegar, shallots, dijon, salt and pepper.',
#      2: 'Cut about a 4 oz piece off or the salmon and place in a food processor or chopper to finely chop. This will help hold the burgers together. With a knife finely chop the remaining salmon, transfer to a large work bowl.',
#      3: 'Heat a large nonstick skillet over medium heat, add the oil and saute shallots and kale. Season with salt and pepper and cook over medium heat until wilted and tender, about 4 to 5 minutes.',
#      4: 'Transfer to the bowl with salmon along with quinoa, Dijon, Old Bay and egg.',
# ...

# %% [markdown]
# # Pickle list

# %% [raw]
# with open('recipe_list.pkl', 'wb') as handle:
#     pickle.dump(recipes, handle, protocol=pickle.HIGHEST_PROTOCOL)

# %%
recipes
# Out:
# [{'Healthy Salmon Quinoa Burgers ': [{'Instructions': {1: 'In a small bowl, whisk the olive oil, vinegar, shallots, dijon, salt and pepper.',
#      2: 'Cut about a 4 oz piece off or the salmon and place in a food processor or chopper to finely chop. This will help hold the burgers together. With a knife finely chop the remaining salmon, transfer to a large work bowl.',
#      3: 'Heat a large nonstick skillet over medium heat, add the oil and saute shallots and kale. Season with salt and pepper and cook over medium heat until wilted and tender, about 4 to 5 minutes.',
#      4: 'Transfer to the bowl with salmon along with quinoa, Dijon, Old Bay and egg.',
# ...

# %%
i = 0
lst = []
for j in recipes:
    for key, value in recipes[i].items():
#         print(key, value[5]['Cuisines'], value[1], value[2])
        print(key, value[2])
        for key1, value1 in value[1].items():
            for x in value1:
                lst.append(x)
        print()
        print(value[5])
        print()
        i+=1
# Out:
# Healthy Salmon Quinoa Burgers  {'Time to Cook': 45}
#
# {'Cuisines': ['american']}
#
# Chicken Parmigiana Burgers Skinnytaste {'Time to Cook': 45}
#
# {'Cuisines': ['mediterranean', 'european', 'italian']}
#
# Pepperoni Pizza Burgers {'Time to Cook': 15}
#
# {'Cuisines': ['american']}
#
# Paleo Burgers with Caramelized Balsamic Onions & Avocado {'Time to Cook': 30}
#
# {'Cuisines': ['american']}
#
# Taco Burgers {'Time to Cook': 25}
#
# {'Cuisines': ['american']}
#
# Super Food Black Bean Vegan Burgers {'Time to Cook': 50}
#
# {'Cuisines': ['american']}
#
# Lentil Mushroom Burgers {'Time to Cook': 70}
#
# {'Cuisines': ['american']}
#
# Onion Burgers {'Time to Cook': 25}
#
# {'Cuisines': ['american']}
#
# Turkey Burgers with Lemon and Mint {'Time to Cook': 30}
#
# {'Cuisines': ['american']}

# %%
# prints out all unique ingredients
lst
# Out:
# ['10 loose cups baby arugula',
#  '1/2 tsp Old Bay',
#  '2 1/2 tbsp champagne vinegar',
#  '3/4 cup cooked quinoa',
#  '1 1/ 4 tsp dijon mustard',
#  '2 tbsp Dijon mustard',
#  '1 large egg, beaten',
#  '1 large pink grapefruit, peeled and diced',
#  '1 cup kale, chopped',
#  'Kosher salt and freshly ground black pepper, to taste',
#  '1 tsp olive oil',
#  '2 1/2 tbsp olive oil',
#  '16 oz wild salmon fillet, skinless',
#  'salt and pepper, to taste',
#  '1/3 cup diced shallots',
#  '2 tbsp minced shallots',
#  '1 cup pomodoro sauce (jar sauce would work)',
#  'Chicken Parmigiana Burgers',
#  '16 oz lean chicken burgers',
#  '4 rolls such as ciabatta rolls',
#  'Sodium 775 mg (without adding salt)',
#  '4 oz part skim mozzarella cheese (I used Alpine Lace)',
#  '1-1/2 pound Ground Beef',
#  '4 whole Kaiser Rolls Or Good Hamburger Buns',
#  '1/2 pound Italian Sausage ( A Little More Is Fine!)',
#  '1/2 teaspoon Italian Seasoning',
#  '8 Tablespoons Jarred Marinara Sauce',
# ...

# %%
recipes[0]
# Out:
# {'Healthy Salmon Quinoa Burgers ': [{'Instructions': {1: 'In a small bowl, whisk the olive oil, vinegar, shallots, dijon, salt and pepper.',
#     2: 'Cut about a 4 oz piece off or the salmon and place in a food processor or chopper to finely chop. This will help hold the burgers together. With a knife finely chop the remaining salmon, transfer to a large work bowl.',
#     3: 'Heat a large nonstick skillet over medium heat, add the oil and saute shallots and kale. Season with salt and pepper and cook over medium heat until wilted and tender, about 4 to 5 minutes.',
#     4: 'Transfer to the bowl with salmon along with quinoa, Dijon, Old Bay and egg.',
# ...
